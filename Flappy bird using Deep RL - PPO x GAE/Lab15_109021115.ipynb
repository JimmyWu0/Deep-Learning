# %% [markdown]
# # Lab15 Flappy bird using Deep RL - PPO x GAE

# %% [markdown]
# ## Lab15_109021115 Chia-Chun Wu

# %%
import numpy as np
import matplotlib.pyplot as plt
import moviepy.editor as mpy
import skimage.transform
from IPython.display import Image, display

import tensorflow as tf
import tensorflow_probability as tfp
import tensorflow.keras.losses as kls

# %%
gpus = tf.config.list_physical_devices("GPU") 
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"  # this line make pop-out window not appear
from ple.games.flappybird import FlappyBird
from ple import PLE

game = FlappyBird()
env = PLE(game, fps=30, display_screen=False)  # environment interface to game
env.reset_game()

test_game = FlappyBird()
test_env = PLE(test_game, fps=30, display_screen=False)
test_env.reset_game()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.9.20)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
path = './movie_f' 
if not os.path.exists(path):
    os.makedirs(path)

# %%
hparas = {
    'image_size': 84,
    'num_stack': 4,
    'action_dim': len(env.getActionSet()),
    'hidden_size': 256,
    'lr': 0.0001,
    'gamma': 0.99,
    'lambda': 0.95,
    'clip_val': 0.2,
    'ppo_epochs': 8,
    'test_epochs': 1,
    'num_steps': 512,
    'mini_batch_size': 64,
    'target_reward': 200,
    'max_episode': 30000,
}

# %%
# Please do not modify this method
def make_anim(images, fps=60, true_image=False):
    duration = len(images) / fps

    def make_frame(t):
        try:
            x = images[int(len(images) / duration * t)]
        except:
            x = images[-1]

        if true_image:
            return x.astype(np.uint8)
        else:
            return ((x + 1) / 2 * 255).astype(np.uint8)

    clip = mpy.VideoClip(make_frame, duration=duration)
    clip.fps = fps
    
    return clip

# %%
def preprocess_screen(screen):
    screen = skimage.transform.rotate(screen, -90, resize=True)
    screen = screen[:400, :]
    screen = skimage.transform.resize(screen, [hparas['image_size'], hparas['image_size'], 1])
    return screen.astype(np.float32)

def frames_to_state(input_frames):  # 1: 1111, 2: 1122, 3: 1233, 4~: 1234 (last 4)
    if(len(input_frames) == 1):
        state = np.concatenate(input_frames*4, axis=-1)
    elif(len(input_frames) == 2):
        state = np.concatenate(input_frames[0:1]*2 + input_frames[1:]*2, axis=-1)
    elif(len(input_frames) == 3):
        state = np.concatenate(input_frames + input_frames[2:], axis=-1)
    else:
        state = np.concatenate(input_frames[-4:], axis=-1)

    return state

# %%
class ActorCriticNetwork(tf.keras.Model):
    def __init__(self, hparas):
        super().__init__()

        self.feature_extractor = tf.keras.Sequential([
          # Convolutional Layers
          tf.keras.layers.Conv2D(filters=32, kernel_size=8, strides=4),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=4, strides=2),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1),
          tf.keras.layers.ReLU(),
          # Embedding Layers
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(hparas['hidden_size']),
          tf.keras.layers.ReLU(),
        ])

        # Actor Network
        self.actor = tf.keras.layers.Dense(hparas['action_dim'], activation='softmax')
        # Critic Network
        self.critic = tf.keras.layers.Dense(1, activation = None)

    def call(self, input):
        x = self.feature_extractor(input)
        action_logits = self.actor(x)
        value = self.critic(x)
        return action_logits, value

# %%
class Agent():
    def __init__(self, hparas):
        self.gamma = hparas['gamma']
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=hparas['lr'])
        self.actor_critic = ActorCriticNetwork(hparas)
        self.clip_pram = hparas['clip_val']
    
    def ppo_iter(self, mini_batch_size, states, actions, log_probs, returns, advantage):
        batch_size = states.shape[0]
        for _ in range(batch_size // mini_batch_size):
            rand_ids = tf.convert_to_tensor(np.random.randint(0, batch_size, mini_batch_size), dtype=tf.int32)
            yield tf.gather(states, rand_ids), tf.gather(actions, rand_ids), tf.gather(log_probs, rand_ids), \
             tf.gather(returns, rand_ids), tf.gather(advantage, rand_ids)
    
    def ppo_update(self, ppo_epochs, mini_batch_size, states, actions, log_probs, discount_rewards, advantages):       
        total_actor_loss = 0
        total_critic_loss = 0
        for _ in range(ppo_epochs):
            for state, action, old_log_probs, reward, advantage in self.ppo_iter(mini_batch_size, states, actions, log_probs, discount_rewards, advantages):
                reward = tf.expand_dims(reward, axis=-1)

                with tf.GradientTape() as tape:
                    prob, value = self.actor_critic(state, training=True)
                    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
                    entropy = tf.math.reduce_mean(dist.entropy())
                    new_log_probs = dist.log_prob(action)

                    # PPO ratio
                    ratio = tf.math.exp(new_log_probs - old_log_probs)
                    surr1 = ratio * advantage
                    surr2 = tf.clip_by_value(ratio, 1.0 - self.clip_pram, 1.0 + self.clip_pram) * advantage

                    actor_loss = tf.math.negative(tf.math.reduce_mean(tf.math.minimum(surr1, surr2))) - 0.1 * entropy
                    critic_loss = 0.5 * tf.math.reduce_mean(kls.mean_squared_error(reward, value))

                    total_loss = actor_loss + critic_loss
            
                # single optimizer
                grads = tape.gradient(total_loss, self.actor_critic.trainable_variables)
                self.optimizer.apply_gradients(zip(grads, self.actor_critic.trainable_variables))
      
                total_actor_loss += actor_loss
                total_critic_loss += critic_loss
        return total_actor_loss, total_critic_loss

# %%
# https://arxiv.org/pdf/1506.02438.pdf
# Equation 16
def compute_gae(rewards, masks, values, gamma, LAMBDA):
    gae = 0
    returns = []
    for i in reversed(range(len(rewards))):
        delta = rewards[i] + gamma * values[i + 1] * masks[i] - values[i]
        gae = delta + gamma * LAMBDA * masks[i] * gae
        returns.append(gae + values[i])

    returns.reverse()
    return returns

# %% [markdown]
# ## Testing Environment

# %%
def test_reward(test_env, agent):
    total_reward = 0
    # Reset the environment
    test_env.reset_game()
    input_frames = [preprocess_screen(test_env.getScreenGrayscale())]

    while not test_env.game_over():

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        action = np.argmax(prob[0].numpy())
        reward = test_env.act(test_env.getActionSet()[action])
        total_reward += reward

        input_frames.append(preprocess_screen(test_env.getScreenGrayscale()))

    return total_reward

# %% [markdown]
# ## Training

# %%
agent = Agent(hparas)
max_episode = hparas['max_episode']
test_per_n_episode = 10
force_save_per_n_episode = 1000
early_stop_reward = 10

start_s = 0
best_reward = -5.0

checkpoint = tf.train.Checkpoint(
    actor_critic = agent.actor_critic,
    optimizer = agent.optimizer,
)

# Load from old checkpoint
# checkpoint.restore('ckpt_dir/ckpt-?')

# %%
ep_reward = []
total_avgr = []
early_stop = False
avg_rewards_list = []

env.reset_game()

for s in range(0, max_episode):
    if early_stop == True:
        break

    rewards = []
    states = []
    actions = []
    log_probs = []
    masks = []
    values = []

    display_frames = [env.getScreenRGB()]
    input_frames = [preprocess_screen(env.getScreenGrayscale())]

    for step in range(hparas['num_steps']):

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        dist = tfp.distributions.Categorical(probs=prob[0], dtype=tf.float32)
        action = dist.sample(1)
        log_prob = dist.log_prob(action)

        reward = env.act(env.getActionSet()[int(action.numpy())])

        done = env.game_over()

        states.append(state)
        actions.append(action)
        values.append(value[0])
        log_probs.append(log_prob)
        rewards.append(tf.convert_to_tensor(reward, dtype=tf.float32))
        masks.append(tf.convert_to_tensor(1-int(done), dtype=tf.float32))

        display_frames.append(env.getScreenRGB())
        input_frames.append(preprocess_screen(env.getScreenGrayscale()))

        if done:
            env.reset_game()
            input_frames = [preprocess_screen(env.getScreenGrayscale())]
  
    _, next_value = agent.actor_critic(state)
    values.append(next_value[0])

    returns = compute_gae(rewards, masks, values, hparas['gamma'], hparas['lambda'])

    returns = tf.concat(returns, axis=0)
    log_probs = tf.concat(log_probs, axis=0)
    values = tf.concat(values, axis=0)
    states = tf.concat(states, axis=0)
    actions = tf.concat(actions, axis=0)
    advantage = returns - values[:-1]

    a_loss, c_loss = agent.ppo_update(hparas['ppo_epochs'], hparas['mini_batch_size'], states, actions, log_probs, returns, advantage)
    print('[Episode %d]  Actor loss: %.5f, Critic loss: %.5f' % (s, a_loss, c_loss))

    if s % test_per_n_episode == 0:
        # test agent hparas['test_epochs'] times to get the average reward
        avg_reward = np.mean([test_reward(test_env, agent) for _ in range(hparas['test_epochs'])])
        print("Test average reward is %.1f, Current best average reward is %.1f\n" % (avg_reward, best_reward))
        avg_rewards_list.append(avg_reward)

        if avg_reward > best_reward:
            best_reward = avg_reward
            agent.actor_critic.save('./save/Actor/model_actor_{}_{}'.format(s, avg_reward), save_format="tf")
            checkpoint.save(file_prefix = './save/checkpoints/ckpt')

    if s % force_save_per_n_episode == 0:
        agent.actor_critic.save('./save/Actor/model_actor_{}_{}'.format(s, avg_reward), save_format="tf")
        checkpoint.save(file_prefix = './save/checkpoints/ckpt')
        clip = make_anim(display_frames, fps=60, true_image=True).rotate(-90)
        clip.write_videofile("movie_f/{}_demo-{}.webm".format('Lab15', s), fps=60)
        display(clip.ipython_display(fps=60, autoplay=1, loop=1, maxduration=120))

    if best_reward >= early_stop_reward:
        early_stop = True
# Out:
# [Episode 0]  Actor loss: 95.77036, Critic loss: 66.21090
# Test average reward is -5.0, Current best average reward is -5.0
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_0_-5.0\assets
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_0_-5.0\assets
# Moviepy - Building video movie_f/Lab15_demo-0.webm.
# Moviepy - Writing video movie_f/Lab15_demo-0.webm
# Moviepy - Done !
# Moviepy - video ready movie_f/Lab15_demo-0.webm
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video autoplay='1' loop='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# WARNING:py.warnings:C:\Users\User\AppData\Local\Temp\ipykernel_15740\2018008081.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   reward = env.act(env.getActionSet()[int(action.numpy())])
# [Episode 1]  Actor loss: 42.46453, Critic loss: 29.80165
# [Episode 2]  Actor loss: 25.55128, Critic loss: 21.09541
# [Episode 3]  Actor loss: 14.49814, Critic loss: 12.05807
# [Episode 4]  Actor loss: 11.39384, Critic loss: 6.29236
# [Episode 5]  Actor loss: 13.52427, Critic loss: 8.26909
# [Episode 6]  Actor loss: 9.28922, Critic loss: 5.41029
# [Episode 7]  Actor loss: 9.34751, Critic loss: 5.63035
# [Episode 8]  Actor loss: -1.68780, Critic loss: 3.83960
# [Episode 9]  Actor loss: 3.70514, Critic loss: 3.59580
# [Episode 10]  Actor loss: -0.01939, Critic loss: 2.69737
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 11]  Actor loss: 1.45098, Critic loss: 3.48116
# [Episode 12]  Actor loss: 2.31742, Critic loss: 3.40674
# [Episode 13]  Actor loss: -8.93342, Critic loss: 3.59459
# [Episode 14]  Actor loss: -8.59711, Critic loss: 1.90234
# [Episode 15]  Actor loss: -5.10448, Critic loss: 2.10117
# [Episode 16]  Actor loss: -5.46974, Critic loss: 2.42328
# [Episode 17]  Actor loss: -8.91442, Critic loss: 2.20310
# [Episode 18]  Actor loss: -7.37987, Critic loss: 2.09069
# [Episode 19]  Actor loss: -4.93442, Critic loss: 1.82566
# [Episode 20]  Actor loss: -5.05711, Critic loss: 1.44404
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 21]  Actor loss: -3.24589, Critic loss: 1.63141
# [Episode 22]  Actor loss: -7.04686, Critic loss: 1.84435
# [Episode 23]  Actor loss: -6.94120, Critic loss: 1.48868
# [Episode 24]  Actor loss: -4.85815, Critic loss: 1.53686
# [Episode 25]  Actor loss: -4.83349, Critic loss: 1.94808
# [Episode 26]  Actor loss: -9.67483, Critic loss: 0.79651
# [Episode 27]  Actor loss: -7.07181, Critic loss: 1.05337
# [Episode 28]  Actor loss: -1.84960, Critic loss: 1.48921
# [Episode 29]  Actor loss: -3.38416, Critic loss: 1.15285
# [Episode 30]  Actor loss: -0.29092, Critic loss: 1.04030
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 31]  Actor loss: -8.87629, Critic loss: 0.69818
# [Episode 32]  Actor loss: -7.94379, Critic loss: 1.09175
# [Episode 33]  Actor loss: -1.54317, Critic loss: 1.30318
# [Episode 34]  Actor loss: -2.88640, Critic loss: 0.75873
# [Episode 35]  Actor loss: -6.67839, Critic loss: 1.83547
# [Episode 36]  Actor loss: -10.70655, Critic loss: 0.88104
# [Episode 37]  Actor loss: -8.89219, Critic loss: 1.97165
# [Episode 38]  Actor loss: -1.84500, Critic loss: 1.15920
# [Episode 39]  Actor loss: -5.30503, Critic loss: 0.85725
# [Episode 40]  Actor loss: -4.42850, Critic loss: 0.88216
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 41]  Actor loss: -1.67248, Critic loss: 1.03775
# [Episode 42]  Actor loss: -10.30238, Critic loss: 0.57803
# [Episode 43]  Actor loss: -7.37661, Critic loss: 0.54204
# [Episode 44]  Actor loss: -4.13172, Critic loss: 0.29684
# [Episode 45]  Actor loss: -3.24893, Critic loss: 0.67497
# [Episode 46]  Actor loss: -7.94335, Critic loss: 0.61623
# [Episode 47]  Actor loss: -5.64802, Critic loss: 1.81966
# [Episode 48]  Actor loss: -3.58156, Critic loss: 1.45132
# [Episode 49]  Actor loss: -3.78092, Critic loss: 1.21450
# [Episode 50]  Actor loss: -3.24276, Critic loss: 1.04486
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 51]  Actor loss: -6.12473, Critic loss: 0.70926
# [Episode 52]  Actor loss: -7.06798, Critic loss: 0.69945
# [Episode 53]  Actor loss: -10.71130, Critic loss: 0.50374
# [Episode 54]  Actor loss: -8.79974, Critic loss: 0.58699
# [Episode 55]  Actor loss: -5.74104, Critic loss: 0.66513
# [Episode 56]  Actor loss: -3.26612, Critic loss: 0.58560
# [Episode 57]  Actor loss: -6.87898, Critic loss: 0.38927
# [Episode 58]  Actor loss: -1.70028, Critic loss: 0.64932
# [Episode 59]  Actor loss: -9.80828, Critic loss: 2.05116
# [Episode 60]  Actor loss: -9.48275, Critic loss: 1.40373
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 61]  Actor loss: -1.82468, Critic loss: 1.08185
# [Episode 62]  Actor loss: -5.33648, Critic loss: 0.73582
# [Episode 63]  Actor loss: -9.43539, Critic loss: 0.58927
# [Episode 64]  Actor loss: -7.51103, Critic loss: 0.36240
# [Episode 65]  Actor loss: -0.02218, Critic loss: 0.61720
# [Episode 66]  Actor loss: -2.36217, Critic loss: 0.45757
# [Episode 67]  Actor loss: -6.65836, Critic loss: 0.40355
# [Episode 68]  Actor loss: -3.05419, Critic loss: 0.49410
# [Episode 69]  Actor loss: 0.85943, Critic loss: 0.83238
# [Episode 70]  Actor loss: -3.22413, Critic loss: 0.73191
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 71]  Actor loss: -2.67101, Critic loss: 0.86734
# [Episode 72]  Actor loss: -7.30152, Critic loss: 0.46321
# [Episode 73]  Actor loss: -9.58224, Critic loss: 0.41791
# [Episode 74]  Actor loss: -6.12611, Critic loss: 0.61649
# [Episode 75]  Actor loss: -6.44744, Critic loss: 0.34247
# [Episode 76]  Actor loss: -4.61273, Critic loss: 0.36735
# [Episode 77]  Actor loss: 1.12030, Critic loss: 0.60359
# [Episode 78]  Actor loss: -2.22267, Critic loss: 0.47905
# [Episode 79]  Actor loss: -6.57359, Critic loss: 0.46419
# [Episode 80]  Actor loss: -9.46736, Critic loss: 0.60735
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 81]  Actor loss: -5.51679, Critic loss: 1.76655
# [Episode 82]  Actor loss: -8.71903, Critic loss: 0.39018
# [Episode 83]  Actor loss: -3.96588, Critic loss: 0.53485
# [Episode 84]  Actor loss: -0.79507, Critic loss: 1.24144
# [Episode 85]  Actor loss: -0.34399, Critic loss: 0.53833
# [Episode 86]  Actor loss: -7.14167, Critic loss: 0.37880
# [Episode 87]  Actor loss: -8.62240, Critic loss: 0.32859
# [Episode 88]  Actor loss: -6.82646, Critic loss: 0.56630
# [Episode 89]  Actor loss: -9.79819, Critic loss: 1.07584
# [Episode 90]  Actor loss: -6.32028, Critic loss: 0.61475
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 91]  Actor loss: -7.74670, Critic loss: 0.75990
# [Episode 92]  Actor loss: -8.25885, Critic loss: 1.10382
# [Episode 93]  Actor loss: -6.18617, Critic loss: 0.91793
# [Episode 94]  Actor loss: -4.03137, Critic loss: 0.63831
# [Episode 95]  Actor loss: -9.71699, Critic loss: 0.87782
# [Episode 96]  Actor loss: -8.10709, Critic loss: 0.26958
# [Episode 97]  Actor loss: -2.01158, Critic loss: 0.65362
# [Episode 98]  Actor loss: -4.97729, Critic loss: 0.45600
# [Episode 99]  Actor loss: -11.67536, Critic loss: 1.47341
# [Episode 100]  Actor loss: -6.76222, Critic loss: 1.20562
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 101]  Actor loss: 0.71691, Critic loss: 0.78565
# [Episode 102]  Actor loss: -8.29842, Critic loss: 0.87383
# [Episode 103]  Actor loss: -5.05658, Critic loss: 0.49216
# [Episode 104]  Actor loss: -2.67937, Critic loss: 0.67025
# [Episode 105]  Actor loss: -3.99438, Critic loss: 0.45025
# [Episode 106]  Actor loss: -5.67649, Critic loss: 0.29012
# [Episode 107]  Actor loss: -0.62979, Critic loss: 0.34174
# [Episode 108]  Actor loss: -3.62897, Critic loss: 0.41479
# [Episode 109]  Actor loss: -3.58694, Critic loss: 0.45457
# [Episode 110]  Actor loss: -4.98298, Critic loss: 0.29680
# Test average reward is -4.0, Current best average reward is -5.0
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_110_-4.0\assets
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_110_-4.0\assets
# WARNING:py.warnings:C:\Users\User\AppData\Local\Temp\ipykernel_15740\2018008081.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   reward = env.act(env.getActionSet()[int(action.numpy())])
# [Episode 111]  Actor loss: -5.51002, Critic loss: 0.75824
# [Episode 112]  Actor loss: -6.28099, Critic loss: 0.44567
# [Episode 113]  Actor loss: -4.36630, Critic loss: 0.54792
# [Episode 114]  Actor loss: -11.56307, Critic loss: 0.40778
# [Episode 115]  Actor loss: -7.67972, Critic loss: 0.39647
# [Episode 116]  Actor loss: -5.36857, Critic loss: 0.45704
# [Episode 117]  Actor loss: -4.08699, Critic loss: 0.46768
# [Episode 118]  Actor loss: -2.99168, Critic loss: 0.58902
# [Episode 119]  Actor loss: -3.20147, Critic loss: 0.60915
# [Episode 120]  Actor loss: -0.44965, Critic loss: 0.43212
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 121]  Actor loss: -5.25910, Critic loss: 0.33972
# [Episode 122]  Actor loss: -7.19448, Critic loss: 0.21179
# [Episode 123]  Actor loss: -3.45953, Critic loss: 0.36992
# [Episode 124]  Actor loss: -6.40689, Critic loss: 0.49288
# [Episode 125]  Actor loss: -5.80698, Critic loss: 0.63598
# [Episode 126]  Actor loss: -6.63951, Critic loss: 0.41718
# [Episode 127]  Actor loss: -8.02742, Critic loss: 0.63883
# [Episode 128]  Actor loss: -8.83338, Critic loss: 0.37703
# [Episode 129]  Actor loss: -4.87991, Critic loss: 0.33806
# [Episode 130]  Actor loss: -1.55604, Critic loss: 0.19218
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 131]  Actor loss: -2.66671, Critic loss: 0.60316
# [Episode 132]  Actor loss: -10.51052, Critic loss: 0.77866
# [Episode 133]  Actor loss: -2.47286, Critic loss: 0.62766
# [Episode 134]  Actor loss: -4.14124, Critic loss: 0.32962
# [Episode 135]  Actor loss: -2.31262, Critic loss: 0.96843
# [Episode 136]  Actor loss: -8.02708, Critic loss: 0.36165
# [Episode 137]  Actor loss: -6.04392, Critic loss: 0.46635
# [Episode 138]  Actor loss: -7.57327, Critic loss: 0.28649
# [Episode 139]  Actor loss: -3.36011, Critic loss: 0.40836
# [Episode 140]  Actor loss: -6.78652, Critic loss: 0.22539
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 141]  Actor loss: -5.46706, Critic loss: 0.23831
# [Episode 142]  Actor loss: -5.46462, Critic loss: 0.36410
# [Episode 143]  Actor loss: -1.09517, Critic loss: 0.41311
# [Episode 144]  Actor loss: -6.19203, Critic loss: 0.40156
# [Episode 145]  Actor loss: -5.27451, Critic loss: 0.30194
# [Episode 146]  Actor loss: -5.91168, Critic loss: 0.24446
# [Episode 147]  Actor loss: -3.05208, Critic loss: 0.54011
# [Episode 148]  Actor loss: -6.90455, Critic loss: 0.29719
# [Episode 149]  Actor loss: -4.06420, Critic loss: 0.31570
# [Episode 150]  Actor loss: -5.62588, Critic loss: 0.28089
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 151]  Actor loss: -6.31786, Critic loss: 0.52881
# [Episode 152]  Actor loss: -0.79231, Critic loss: 0.50961
# [Episode 153]  Actor loss: -4.89154, Critic loss: 0.27015
# [Episode 154]  Actor loss: -3.01257, Critic loss: 0.41050
# [Episode 155]  Actor loss: -5.75436, Critic loss: 0.44501
# [Episode 156]  Actor loss: -7.47708, Critic loss: 0.41171
# [Episode 157]  Actor loss: -8.60826, Critic loss: 0.64344
# [Episode 158]  Actor loss: -5.46038, Critic loss: 0.33743
# [Episode 159]  Actor loss: -4.29465, Critic loss: 0.39116
# [Episode 160]  Actor loss: -2.95197, Critic loss: 0.34008
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 161]  Actor loss: -3.20585, Critic loss: 0.39268
# [Episode 162]  Actor loss: -6.92366, Critic loss: 0.70692
# [Episode 163]  Actor loss: -4.33240, Critic loss: 0.38650
# [Episode 164]  Actor loss: -8.91251, Critic loss: 0.33081
# [Episode 165]  Actor loss: -7.01292, Critic loss: 0.40373
# [Episode 166]  Actor loss: -2.53228, Critic loss: 0.56225
# [Episode 167]  Actor loss: -4.03075, Critic loss: 0.53141
# [Episode 168]  Actor loss: -1.74517, Critic loss: 0.34888
# [Episode 169]  Actor loss: -3.39357, Critic loss: 0.44883
# [Episode 170]  Actor loss: -6.35063, Critic loss: 0.33754
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 171]  Actor loss: -1.28822, Critic loss: 0.41452
# [Episode 172]  Actor loss: -9.71820, Critic loss: 0.31225
# [Episode 173]  Actor loss: -5.20000, Critic loss: 0.41280
# [Episode 174]  Actor loss: -3.92059, Critic loss: 0.53858
# [Episode 175]  Actor loss: -0.62203, Critic loss: 0.40515
# [Episode 176]  Actor loss: -4.10458, Critic loss: 0.38759
# [Episode 177]  Actor loss: -2.49092, Critic loss: 0.42548
# [Episode 178]  Actor loss: -11.10736, Critic loss: 0.29996
# [Episode 179]  Actor loss: -2.42275, Critic loss: 0.38026
# [Episode 180]  Actor loss: -1.24764, Critic loss: 0.29548
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 181]  Actor loss: -0.79220, Critic loss: 0.49284
# [Episode 182]  Actor loss: -5.10560, Critic loss: 0.32713
# [Episode 183]  Actor loss: -8.49561, Critic loss: 0.80252
# [Episode 184]  Actor loss: -8.24548, Critic loss: 1.07810
# [Episode 185]  Actor loss: -6.10313, Critic loss: 0.54506
# [Episode 186]  Actor loss: -6.59124, Critic loss: 0.28654
# [Episode 187]  Actor loss: -1.84411, Critic loss: 0.33209
# [Episode 188]  Actor loss: -5.14332, Critic loss: 0.34012
# [Episode 189]  Actor loss: -3.79145, Critic loss: 0.38900
# [Episode 190]  Actor loss: -8.23640, Critic loss: 0.87558
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 191]  Actor loss: -3.89283, Critic loss: 0.85368
# [Episode 192]  Actor loss: -5.60352, Critic loss: 0.54564
# [Episode 193]  Actor loss: -4.10088, Critic loss: 0.53257
# [Episode 194]  Actor loss: -4.27013, Critic loss: 0.33390
# [Episode 195]  Actor loss: -3.26831, Critic loss: 0.26216
# [Episode 196]  Actor loss: -9.68061, Critic loss: 0.66283
# [Episode 197]  Actor loss: -6.33378, Critic loss: 0.43656
# [Episode 198]  Actor loss: -4.54959, Critic loss: 0.26258
# [Episode 199]  Actor loss: -7.87980, Critic loss: 0.31706
# [Episode 200]  Actor loss: -1.35008, Critic loss: 0.42475
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 201]  Actor loss: -3.86768, Critic loss: 0.30545
# [Episode 202]  Actor loss: -5.64992, Critic loss: 0.36234
# [Episode 203]  Actor loss: -6.91181, Critic loss: 0.84085
# [Episode 204]  Actor loss: -4.72897, Critic loss: 0.59919
# [Episode 205]  Actor loss: -5.19996, Critic loss: 0.52825
# [Episode 206]  Actor loss: -6.84141, Critic loss: 0.37657
# [Episode 207]  Actor loss: -6.38359, Critic loss: 0.45368
# [Episode 208]  Actor loss: -7.64977, Critic loss: 0.48651
# [Episode 209]  Actor loss: -4.83193, Critic loss: 0.57573
# [Episode 210]  Actor loss: -3.77163, Critic loss: 0.55699
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 211]  Actor loss: -3.93813, Critic loss: 0.48082
# [Episode 212]  Actor loss: -5.28201, Critic loss: 0.34450
# [Episode 213]  Actor loss: -6.73573, Critic loss: 0.38531
# [Episode 214]  Actor loss: -5.12260, Critic loss: 0.51462
# [Episode 215]  Actor loss: -6.01277, Critic loss: 0.26034
# [Episode 216]  Actor loss: -5.08279, Critic loss: 0.34226
# [Episode 217]  Actor loss: -6.44406, Critic loss: 0.56894
# [Episode 218]  Actor loss: -11.16898, Critic loss: 1.07797
# [Episode 219]  Actor loss: -6.72468, Critic loss: 0.95668
# [Episode 220]  Actor loss: -2.76941, Critic loss: 0.58828
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 221]  Actor loss: 1.79678, Critic loss: 0.49522
# [Episode 222]  Actor loss: -5.61934, Critic loss: 1.49857
# [Episode 223]  Actor loss: -4.04860, Critic loss: 0.80120
# [Episode 224]  Actor loss: -3.01745, Critic loss: 0.43491
# [Episode 225]  Actor loss: -4.61691, Critic loss: 0.37639
# [Episode 226]  Actor loss: -5.19774, Critic loss: 0.47278
# [Episode 227]  Actor loss: -7.12956, Critic loss: 0.55586
# [Episode 228]  Actor loss: -4.64250, Critic loss: 0.73690
# [Episode 229]  Actor loss: -4.01285, Critic loss: 0.60089
# [Episode 230]  Actor loss: -4.82216, Critic loss: 0.35135
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 231]  Actor loss: -4.27371, Critic loss: 0.64059
# [Episode 232]  Actor loss: -3.91401, Critic loss: 0.68682
# [Episode 233]  Actor loss: -3.64822, Critic loss: 0.33878
# [Episode 234]  Actor loss: -4.19064, Critic loss: 0.47833
# [Episode 235]  Actor loss: -4.16643, Critic loss: 0.50877
# [Episode 236]  Actor loss: -4.44527, Critic loss: 0.37939
# [Episode 237]  Actor loss: -7.17461, Critic loss: 0.78928
# [Episode 238]  Actor loss: -3.29474, Critic loss: 0.27641
# [Episode 239]  Actor loss: -4.87437, Critic loss: 0.36777
# [Episode 240]  Actor loss: -5.70905, Critic loss: 0.82227
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 241]  Actor loss: -3.14711, Critic loss: 0.38334
# [Episode 242]  Actor loss: -1.11096, Critic loss: 0.34996
# [Episode 243]  Actor loss: -3.76520, Critic loss: 0.31266
# [Episode 244]  Actor loss: -3.36884, Critic loss: 0.55604
# [Episode 245]  Actor loss: -3.92899, Critic loss: 0.32053
# [Episode 246]  Actor loss: -6.89148, Critic loss: 0.30544
# [Episode 247]  Actor loss: -6.79690, Critic loss: 0.27332
# [Episode 248]  Actor loss: -1.93120, Critic loss: 0.33743
# [Episode 249]  Actor loss: -7.42138, Critic loss: 0.29521
# [Episode 250]  Actor loss: -6.13682, Critic loss: 0.95773
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 251]  Actor loss: -1.87318, Critic loss: 0.40694
# [Episode 252]  Actor loss: -5.20946, Critic loss: 0.42612
# [Episode 253]  Actor loss: -5.92307, Critic loss: 0.32938
# [Episode 254]  Actor loss: -8.47055, Critic loss: 0.83765
# [Episode 255]  Actor loss: -1.28518, Critic loss: 0.61921
# [Episode 256]  Actor loss: -2.95430, Critic loss: 0.32414
# [Episode 257]  Actor loss: -5.20537, Critic loss: 0.38550
# [Episode 258]  Actor loss: -1.93621, Critic loss: 0.35681
# [Episode 259]  Actor loss: -3.25526, Critic loss: 0.32603
# [Episode 260]  Actor loss: -6.23636, Critic loss: 0.50626
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 261]  Actor loss: -3.94700, Critic loss: 0.42408
# [Episode 262]  Actor loss: -4.85516, Critic loss: 0.29587
# [Episode 263]  Actor loss: -4.02614, Critic loss: 0.49381
# [Episode 264]  Actor loss: -3.78231, Critic loss: 0.27857
# [Episode 265]  Actor loss: -7.17665, Critic loss: 0.43626
# [Episode 266]  Actor loss: -6.53785, Critic loss: 0.54098
# [Episode 267]  Actor loss: -7.91289, Critic loss: 0.69339
# [Episode 268]  Actor loss: -7.59685, Critic loss: 0.92147
# [Episode 269]  Actor loss: -4.65678, Critic loss: 0.58618
# [Episode 270]  Actor loss: -6.23826, Critic loss: 0.43890
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 271]  Actor loss: -3.76941, Critic loss: 0.41037
# [Episode 272]  Actor loss: -1.37606, Critic loss: 0.41793
# [Episode 273]  Actor loss: -1.78131, Critic loss: 0.62758
# [Episode 274]  Actor loss: -3.60282, Critic loss: 0.34308
# [Episode 275]  Actor loss: -4.82555, Critic loss: 0.50567
# [Episode 276]  Actor loss: -3.73462, Critic loss: 0.52995
# [Episode 277]  Actor loss: -3.87265, Critic loss: 0.38912
# [Episode 278]  Actor loss: -7.26256, Critic loss: 0.69637
# [Episode 279]  Actor loss: -6.51990, Critic loss: 0.52147
# [Episode 280]  Actor loss: -3.21489, Critic loss: 0.40161
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 281]  Actor loss: -1.18160, Critic loss: 0.38857
# [Episode 282]  Actor loss: -2.75803, Critic loss: 0.27154
# [Episode 283]  Actor loss: -2.26027, Critic loss: 0.41408
# [Episode 284]  Actor loss: -1.06704, Critic loss: 0.45921
# [Episode 285]  Actor loss: -5.79739, Critic loss: 0.35466
# [Episode 286]  Actor loss: -3.36929, Critic loss: 0.31083
# [Episode 287]  Actor loss: -6.13799, Critic loss: 0.28241
# [Episode 288]  Actor loss: -1.50591, Critic loss: 0.33600
# [Episode 289]  Actor loss: -7.26995, Critic loss: 0.69280
# [Episode 290]  Actor loss: -3.39481, Critic loss: 0.54101
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 291]  Actor loss: -6.75418, Critic loss: 0.52516
# [Episode 292]  Actor loss: -6.49493, Critic loss: 0.23075
# [Episode 293]  Actor loss: -4.69674, Critic loss: 0.34122
# [Episode 294]  Actor loss: -4.75080, Critic loss: 0.29948
# [Episode 295]  Actor loss: -3.62214, Critic loss: 0.42694
# [Episode 296]  Actor loss: -4.90574, Critic loss: 0.36597
# [Episode 297]  Actor loss: -2.84527, Critic loss: 0.39340
# [Episode 298]  Actor loss: -3.84157, Critic loss: 0.28659
# [Episode 299]  Actor loss: -6.45426, Critic loss: 0.39542
# [Episode 300]  Actor loss: -7.17759, Critic loss: 0.37515
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 301]  Actor loss: -5.89188, Critic loss: 0.37251
# [Episode 302]  Actor loss: -3.61617, Critic loss: 0.43017
# [Episode 303]  Actor loss: -5.25292, Critic loss: 0.23674
# [Episode 304]  Actor loss: -3.07611, Critic loss: 0.35884
# [Episode 305]  Actor loss: -7.25125, Critic loss: 0.30607
# [Episode 306]  Actor loss: -5.52855, Critic loss: 0.27251
# [Episode 307]  Actor loss: -4.73505, Critic loss: 0.23448
# [Episode 308]  Actor loss: -2.00803, Critic loss: 0.47415
# [Episode 309]  Actor loss: -4.61608, Critic loss: 0.33994
# [Episode 310]  Actor loss: -6.94373, Critic loss: 0.36640
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 311]  Actor loss: -5.25537, Critic loss: 0.29313
# [Episode 312]  Actor loss: -3.04799, Critic loss: 0.27087
# [Episode 313]  Actor loss: -4.53614, Critic loss: 0.38910
# [Episode 314]  Actor loss: -7.19413, Critic loss: 0.29043
# [Episode 315]  Actor loss: -3.85641, Critic loss: 0.17680
# [Episode 316]  Actor loss: -1.19241, Critic loss: 0.70140
# [Episode 317]  Actor loss: -5.16954, Critic loss: 0.28189
# [Episode 318]  Actor loss: -2.26083, Critic loss: 0.35092
# [Episode 319]  Actor loss: -2.05269, Critic loss: 0.29311
# [Episode 320]  Actor loss: -2.04786, Critic loss: 0.29901
# Test average reward is -4.0, Current best average reward is -4.0
#
# [Episode 321]  Actor loss: -4.18718, Critic loss: 0.32568
# [Episode 322]  Actor loss: -3.18873, Critic loss: 0.38095
# [Episode 323]  Actor loss: -6.46177, Critic loss: 0.28838
# [Episode 324]  Actor loss: -7.59878, Critic loss: 0.37333
# [Episode 325]  Actor loss: -4.22821, Critic loss: 0.25407
# [Episode 326]  Actor loss: -5.53725, Critic loss: 0.35154
# [Episode 327]  Actor loss: -6.71438, Critic loss: 0.33422
# [Episode 328]  Actor loss: -8.38305, Critic loss: 0.30711
# [Episode 329]  Actor loss: -6.02164, Critic loss: 0.30541
# [Episode 330]  Actor loss: -4.92952, Critic loss: 0.27969
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 331]  Actor loss: -4.76067, Critic loss: 0.51799
# [Episode 332]  Actor loss: -5.95507, Critic loss: 0.32728
# [Episode 333]  Actor loss: -5.22335, Critic loss: 0.36171
# [Episode 334]  Actor loss: -2.78951, Critic loss: 0.45790
# [Episode 335]  Actor loss: -5.86780, Critic loss: 0.32810
# [Episode 336]  Actor loss: -3.08401, Critic loss: 0.27811
# [Episode 337]  Actor loss: -5.77954, Critic loss: 0.41717
# [Episode 338]  Actor loss: -3.91274, Critic loss: 0.31651
# [Episode 339]  Actor loss: -8.54845, Critic loss: 0.56849
# [Episode 340]  Actor loss: -6.77027, Critic loss: 0.29235
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 341]  Actor loss: -7.54453, Critic loss: 0.21637
# [Episode 342]  Actor loss: -4.60851, Critic loss: 0.23435
# [Episode 343]  Actor loss: -1.72557, Critic loss: 0.60981
# [Episode 344]  Actor loss: -4.41425, Critic loss: 0.48443
# [Episode 345]  Actor loss: -9.38792, Critic loss: 0.94187
# [Episode 346]  Actor loss: -7.53065, Critic loss: 0.91100
# [Episode 347]  Actor loss: -5.71782, Critic loss: 0.79934
# [Episode 348]  Actor loss: -2.75383, Critic loss: 0.34190
# [Episode 349]  Actor loss: -4.25166, Critic loss: 0.62271
# [Episode 350]  Actor loss: -0.21656, Critic loss: 0.51777
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 351]  Actor loss: -5.79028, Critic loss: 0.36963
# [Episode 352]  Actor loss: -6.05746, Critic loss: 0.36624
# [Episode 353]  Actor loss: -2.95689, Critic loss: 0.27498
# [Episode 354]  Actor loss: -6.88731, Critic loss: 0.22253
# [Episode 355]  Actor loss: -0.00751, Critic loss: 0.29191
# [Episode 356]  Actor loss: -3.80458, Critic loss: 0.24823
# [Episode 357]  Actor loss: -3.99047, Critic loss: 0.19931
# [Episode 358]  Actor loss: -5.27492, Critic loss: 0.32901
# [Episode 359]  Actor loss: -3.54208, Critic loss: 0.34898
# [Episode 360]  Actor loss: -3.16863, Critic loss: 0.36759
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 361]  Actor loss: -5.35259, Critic loss: 0.25265
# [Episode 362]  Actor loss: -8.83636, Critic loss: 0.58149
# [Episode 363]  Actor loss: -2.99405, Critic loss: 0.47696
# [Episode 364]  Actor loss: -10.11853, Critic loss: 0.52680
# [Episode 365]  Actor loss: -4.17405, Critic loss: 0.34004
# [Episode 366]  Actor loss: -10.27842, Critic loss: 0.72711
# [Episode 367]  Actor loss: -5.01336, Critic loss: 0.35789
# [Episode 368]  Actor loss: -1.97296, Critic loss: 0.30569
# [Episode 369]  Actor loss: -4.99744, Critic loss: 0.23282
# [Episode 370]  Actor loss: -5.78825, Critic loss: 0.20487
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 371]  Actor loss: -4.09515, Critic loss: 0.28383
# [Episode 372]  Actor loss: -3.54601, Critic loss: 0.25124
# [Episode 373]  Actor loss: -3.65727, Critic loss: 0.30825
# [Episode 374]  Actor loss: -3.80805, Critic loss: 0.42470
# [Episode 375]  Actor loss: -5.10398, Critic loss: 0.26202
# [Episode 376]  Actor loss: -5.22799, Critic loss: 0.80744
# [Episode 377]  Actor loss: -4.79354, Critic loss: 0.42719
# [Episode 378]  Actor loss: -4.61530, Critic loss: 0.26132
# [Episode 379]  Actor loss: -1.26391, Critic loss: 0.34621
# [Episode 380]  Actor loss: -5.53832, Critic loss: 0.36552
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 381]  Actor loss: -6.18014, Critic loss: 0.36837
# [Episode 382]  Actor loss: -3.83197, Critic loss: 0.33738
# [Episode 383]  Actor loss: -6.63611, Critic loss: 0.25986
# [Episode 384]  Actor loss: -3.83061, Critic loss: 0.38223
# [Episode 385]  Actor loss: -5.84436, Critic loss: 0.44223
# [Episode 386]  Actor loss: -3.74577, Critic loss: 0.41189
# [Episode 387]  Actor loss: -6.35944, Critic loss: 0.49616
# [Episode 388]  Actor loss: -5.51406, Critic loss: 0.25156
# [Episode 389]  Actor loss: -6.63258, Critic loss: 0.35926
# [Episode 390]  Actor loss: -4.56900, Critic loss: 0.45585
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 391]  Actor loss: -4.17318, Critic loss: 0.35176
# [Episode 392]  Actor loss: -1.48236, Critic loss: 0.36971
# [Episode 393]  Actor loss: 0.57027, Critic loss: 0.39638
# [Episode 394]  Actor loss: -2.71790, Critic loss: 0.27624
# [Episode 395]  Actor loss: -6.15559, Critic loss: 0.27262
# [Episode 396]  Actor loss: -4.85437, Critic loss: 0.20425
# [Episode 397]  Actor loss: -6.95096, Critic loss: 0.23503
# [Episode 398]  Actor loss: -5.92333, Critic loss: 0.25280
# [Episode 399]  Actor loss: -5.12349, Critic loss: 0.27297
# [Episode 400]  Actor loss: -6.94048, Critic loss: 0.22731
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 401]  Actor loss: -4.48951, Critic loss: 0.36281
# [Episode 402]  Actor loss: -1.96226, Critic loss: 0.31916
# [Episode 403]  Actor loss: -0.49583, Critic loss: 0.91852
# [Episode 404]  Actor loss: -7.62806, Critic loss: 0.33422
# [Episode 405]  Actor loss: -5.60891, Critic loss: 1.15446
# [Episode 406]  Actor loss: 0.63577, Critic loss: 0.70873
# [Episode 407]  Actor loss: -1.52676, Critic loss: 0.63222
# [Episode 408]  Actor loss: -9.75613, Critic loss: 0.63235
# [Episode 409]  Actor loss: -2.78391, Critic loss: 0.33125
# [Episode 410]  Actor loss: -3.55884, Critic loss: 0.38308
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 411]  Actor loss: -3.43391, Critic loss: 0.51276
# [Episode 412]  Actor loss: -2.93657, Critic loss: 0.29620
# [Episode 413]  Actor loss: -4.46656, Critic loss: 0.43268
# [Episode 414]  Actor loss: -10.02037, Critic loss: 0.35047
# [Episode 415]  Actor loss: -3.78609, Critic loss: 0.26971
# [Episode 416]  Actor loss: -3.05920, Critic loss: 0.21198
# [Episode 417]  Actor loss: -4.03465, Critic loss: 0.28665
# [Episode 418]  Actor loss: -4.88035, Critic loss: 0.50680
# [Episode 419]  Actor loss: -6.06135, Critic loss: 0.22058
# [Episode 420]  Actor loss: -3.85862, Critic loss: 0.40705
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 421]  Actor loss: -3.96208, Critic loss: 0.36096
# [Episode 422]  Actor loss: -3.92168, Critic loss: 0.36255
# [Episode 423]  Actor loss: -4.40286, Critic loss: 0.37540
# [Episode 424]  Actor loss: -5.22602, Critic loss: 0.30005
# [Episode 425]  Actor loss: -5.29992, Critic loss: 0.30896
# [Episode 426]  Actor loss: -9.79186, Critic loss: 0.26796
# [Episode 427]  Actor loss: -6.45101, Critic loss: 0.55443
# [Episode 428]  Actor loss: -2.55681, Critic loss: 0.66791
# [Episode 429]  Actor loss: -5.92334, Critic loss: 0.44844
# [Episode 430]  Actor loss: -8.86969, Critic loss: 0.61076
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 431]  Actor loss: -7.23504, Critic loss: 0.75611
# [Episode 432]  Actor loss: -4.78120, Critic loss: 0.41342
# [Episode 433]  Actor loss: -1.50264, Critic loss: 0.30134
# [Episode 434]  Actor loss: -2.40822, Critic loss: 0.39462
# [Episode 435]  Actor loss: -6.34972, Critic loss: 1.12062
# [Episode 436]  Actor loss: -2.13044, Critic loss: 0.67398
# [Episode 437]  Actor loss: -2.81487, Critic loss: 0.51076
# [Episode 438]  Actor loss: -4.11645, Critic loss: 0.40453
# [Episode 439]  Actor loss: -7.71882, Critic loss: 1.03799
# [Episode 440]  Actor loss: -4.10535, Critic loss: 0.67931
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 441]  Actor loss: 1.44200, Critic loss: 0.58738
# [Episode 442]  Actor loss: -5.03317, Critic loss: 0.41713
# [Episode 443]  Actor loss: -4.31861, Critic loss: 0.37226
# [Episode 444]  Actor loss: -5.12041, Critic loss: 0.31861
# [Episode 445]  Actor loss: -2.53336, Critic loss: 0.23920
# [Episode 446]  Actor loss: -5.23619, Critic loss: 0.28019
# [Episode 447]  Actor loss: -7.88838, Critic loss: 0.25056
# [Episode 448]  Actor loss: -5.01833, Critic loss: 1.16700
# [Episode 449]  Actor loss: -6.18391, Critic loss: 0.76917
# [Episode 450]  Actor loss: -3.56960, Critic loss: 1.00792
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 451]  Actor loss: -5.05175, Critic loss: 0.66307
# [Episode 452]  Actor loss: -5.13413, Critic loss: 0.86597
# [Episode 453]  Actor loss: -2.22523, Critic loss: 0.72924
# [Episode 454]  Actor loss: 0.01686, Critic loss: 0.36961
# [Episode 455]  Actor loss: -0.62661, Critic loss: 0.45423
# [Episode 456]  Actor loss: -5.16090, Critic loss: 0.25537
# [Episode 457]  Actor loss: -3.15554, Critic loss: 0.26297
# [Episode 458]  Actor loss: -5.80870, Critic loss: 0.38356
# [Episode 459]  Actor loss: -5.69844, Critic loss: 0.31073
# [Episode 460]  Actor loss: -6.56571, Critic loss: 0.48518
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 461]  Actor loss: -4.96076, Critic loss: 0.56241
# [Episode 462]  Actor loss: -8.83572, Critic loss: 1.21169
# [Episode 463]  Actor loss: 1.20127, Critic loss: 0.51339
# [Episode 464]  Actor loss: -4.06806, Critic loss: 0.47727
# [Episode 465]  Actor loss: -3.30552, Critic loss: 0.24718
# [Episode 466]  Actor loss: -4.61629, Critic loss: 0.31119
# [Episode 467]  Actor loss: -4.69450, Critic loss: 0.32542
# [Episode 468]  Actor loss: -3.26711, Critic loss: 0.27681
# [Episode 469]  Actor loss: -8.73373, Critic loss: 0.57181
# [Episode 470]  Actor loss: -4.37493, Critic loss: 0.38478
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 471]  Actor loss: -5.68304, Critic loss: 0.40040
# [Episode 472]  Actor loss: -6.75181, Critic loss: 0.48141
# [Episode 473]  Actor loss: -8.71605, Critic loss: 0.98823
# [Episode 474]  Actor loss: -1.25210, Critic loss: 0.67809
# [Episode 475]  Actor loss: -8.82025, Critic loss: 0.65515
# [Episode 476]  Actor loss: -4.09871, Critic loss: 0.46211
# [Episode 477]  Actor loss: -7.65923, Critic loss: 0.94360
# [Episode 478]  Actor loss: -2.66557, Critic loss: 0.43481
# [Episode 479]  Actor loss: -0.92757, Critic loss: 0.28896
# [Episode 480]  Actor loss: -2.31241, Critic loss: 0.28661
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 481]  Actor loss: -5.13546, Critic loss: 0.43576
# [Episode 482]  Actor loss: -5.68772, Critic loss: 0.76245
# [Episode 483]  Actor loss: -4.47048, Critic loss: 0.48971
# [Episode 484]  Actor loss: -3.82413, Critic loss: 0.39069
# [Episode 485]  Actor loss: -5.09727, Critic loss: 0.34661
# [Episode 486]  Actor loss: -4.37378, Critic loss: 0.38815
# [Episode 487]  Actor loss: -9.57863, Critic loss: 1.12425
# [Episode 488]  Actor loss: -4.83787, Critic loss: 1.09571
# [Episode 489]  Actor loss: 1.12135, Critic loss: 0.37663
# [Episode 490]  Actor loss: -8.83540, Critic loss: 0.98408
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 491]  Actor loss: -2.52664, Critic loss: 1.33314
# [Episode 492]  Actor loss: -3.68781, Critic loss: 0.51027
# [Episode 493]  Actor loss: -5.49206, Critic loss: 0.49722
# [Episode 494]  Actor loss: -9.54735, Critic loss: 1.27916
# [Episode 495]  Actor loss: -4.89550, Critic loss: 0.33169
# [Episode 496]  Actor loss: -5.70368, Critic loss: 0.27885
# [Episode 497]  Actor loss: -6.27840, Critic loss: 0.36698
# [Episode 498]  Actor loss: -5.82027, Critic loss: 0.29703
# [Episode 499]  Actor loss: -4.68384, Critic loss: 0.25182
# [Episode 500]  Actor loss: -5.52040, Critic loss: 0.34544
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 501]  Actor loss: -2.66717, Critic loss: 0.33736
# [Episode 502]  Actor loss: -6.55940, Critic loss: 0.42490
# [Episode 503]  Actor loss: -8.06963, Critic loss: 0.43664
# [Episode 504]  Actor loss: -5.02504, Critic loss: 0.41908
# [Episode 505]  Actor loss: -1.14692, Critic loss: 0.36600
# [Episode 506]  Actor loss: -3.83195, Critic loss: 0.52282
# [Episode 507]  Actor loss: -5.65740, Critic loss: 0.50359
# [Episode 508]  Actor loss: -1.82164, Critic loss: 0.34028
# [Episode 509]  Actor loss: -1.76451, Critic loss: 0.55539
# [Episode 510]  Actor loss: -4.61051, Critic loss: 0.33401
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 511]  Actor loss: -5.65219, Critic loss: 0.45363
# [Episode 512]  Actor loss: -12.39431, Critic loss: 0.79083
# [Episode 513]  Actor loss: -5.82563, Critic loss: 0.61826
# [Episode 514]  Actor loss: -6.70662, Critic loss: 0.76467
# [Episode 515]  Actor loss: -6.24164, Critic loss: 0.64244
# [Episode 516]  Actor loss: -1.23091, Critic loss: 0.78512
# [Episode 517]  Actor loss: -0.11120, Critic loss: 0.55605
# [Episode 518]  Actor loss: -1.63309, Critic loss: 0.34145
# [Episode 519]  Actor loss: -10.07498, Critic loss: 0.73737
# [Episode 520]  Actor loss: 0.28020, Critic loss: 0.59159
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 521]  Actor loss: -3.93282, Critic loss: 0.24400
# [Episode 522]  Actor loss: -7.20519, Critic loss: 0.59485
# [Episode 523]  Actor loss: -0.29027, Critic loss: 0.52813
# [Episode 524]  Actor loss: -8.24962, Critic loss: 0.79531
# [Episode 525]  Actor loss: -2.93690, Critic loss: 0.32397
# [Episode 526]  Actor loss: -5.71165, Critic loss: 0.22821
# [Episode 527]  Actor loss: -1.96916, Critic loss: 0.51770
# [Episode 528]  Actor loss: -8.63112, Critic loss: 0.86256
# [Episode 529]  Actor loss: -11.88937, Critic loss: 0.84317
# [Episode 530]  Actor loss: -1.90534, Critic loss: 0.56060
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 531]  Actor loss: -4.38614, Critic loss: 0.76963
# [Episode 532]  Actor loss: -9.43503, Critic loss: 1.13704
# [Episode 533]  Actor loss: -1.99961, Critic loss: 0.61094
# [Episode 534]  Actor loss: -3.02476, Critic loss: 0.45662
# [Episode 535]  Actor loss: -6.99060, Critic loss: 0.27292
# [Episode 536]  Actor loss: -4.17367, Critic loss: 0.37792
# [Episode 537]  Actor loss: -7.23841, Critic loss: 0.22400
# [Episode 538]  Actor loss: -4.40794, Critic loss: 0.38825
# [Episode 539]  Actor loss: -5.48446, Critic loss: 0.65192
# [Episode 540]  Actor loss: -9.37205, Critic loss: 1.01680
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 541]  Actor loss: -5.47185, Critic loss: 0.63021
# [Episode 542]  Actor loss: -13.71177, Critic loss: 0.95975
# [Episode 543]  Actor loss: -12.36034, Critic loss: 1.06404
# [Episode 544]  Actor loss: -1.90218, Critic loss: 0.43487
# [Episode 545]  Actor loss: -7.32354, Critic loss: 1.00892
# [Episode 546]  Actor loss: -5.88951, Critic loss: 1.07690
# [Episode 547]  Actor loss: -2.32946, Critic loss: 0.68626
# [Episode 548]  Actor loss: -4.62470, Critic loss: 0.19896
# [Episode 549]  Actor loss: -6.03826, Critic loss: 0.37524
# [Episode 550]  Actor loss: -3.38106, Critic loss: 0.26728
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 551]  Actor loss: -6.00886, Critic loss: 0.78529
# [Episode 552]  Actor loss: -8.92303, Critic loss: 0.47832
# [Episode 553]  Actor loss: -3.92335, Critic loss: 0.35440
# [Episode 554]  Actor loss: -3.23395, Critic loss: 0.35111
# [Episode 555]  Actor loss: -1.43568, Critic loss: 0.54270
# [Episode 556]  Actor loss: -8.00641, Critic loss: 0.68214
# [Episode 557]  Actor loss: -3.55416, Critic loss: 0.28616
# [Episode 558]  Actor loss: -4.31476, Critic loss: 0.69469
# [Episode 559]  Actor loss: -0.86109, Critic loss: 0.59338
# [Episode 560]  Actor loss: -8.13291, Critic loss: 0.97334
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 561]  Actor loss: 0.18069, Critic loss: 0.70527
# [Episode 562]  Actor loss: -1.67318, Critic loss: 0.57678
# [Episode 563]  Actor loss: -2.33249, Critic loss: 0.55389
# [Episode 564]  Actor loss: -5.81008, Critic loss: 0.73204
# [Episode 565]  Actor loss: -9.17002, Critic loss: 0.68922
# [Episode 566]  Actor loss: -4.71077, Critic loss: 0.86061
# [Episode 567]  Actor loss: -6.07499, Critic loss: 0.80048
# [Episode 568]  Actor loss: -11.05174, Critic loss: 1.52805
# [Episode 569]  Actor loss: -3.75117, Critic loss: 0.79971
# [Episode 570]  Actor loss: -5.78868, Critic loss: 1.48481
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 571]  Actor loss: -8.77365, Critic loss: 1.37066
# [Episode 572]  Actor loss: -1.35435, Critic loss: 1.02574
# [Episode 573]  Actor loss: -5.68945, Critic loss: 1.04825
# [Episode 574]  Actor loss: -4.61156, Critic loss: 0.83611
# [Episode 575]  Actor loss: -6.62348, Critic loss: 1.13730
# [Episode 576]  Actor loss: -1.38704, Critic loss: 0.39455
# [Episode 577]  Actor loss: -4.76609, Critic loss: 0.50518
# [Episode 578]  Actor loss: -1.35613, Critic loss: 0.36818
# [Episode 579]  Actor loss: -4.77387, Critic loss: 0.50828
# [Episode 580]  Actor loss: -9.49430, Critic loss: 1.07880
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 581]  Actor loss: 1.53827, Critic loss: 0.77679
# [Episode 582]  Actor loss: -4.11241, Critic loss: 0.49971
# [Episode 583]  Actor loss: -6.44503, Critic loss: 0.62442
# [Episode 584]  Actor loss: 1.86838, Critic loss: 0.60577
# [Episode 585]  Actor loss: -0.13942, Critic loss: 0.70460
# [Episode 586]  Actor loss: -7.56183, Critic loss: 0.59232
# [Episode 587]  Actor loss: -0.52026, Critic loss: 0.42652
# [Episode 588]  Actor loss: -1.23735, Critic loss: 0.25663
# [Episode 589]  Actor loss: -5.23621, Critic loss: 0.68589
# [Episode 590]  Actor loss: -6.67689, Critic loss: 0.88474
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 591]  Actor loss: -5.57709, Critic loss: 0.63967
# [Episode 592]  Actor loss: -3.62736, Critic loss: 0.48323
# [Episode 593]  Actor loss: -2.16625, Critic loss: 0.57676
# [Episode 594]  Actor loss: -9.01206, Critic loss: 0.72363
# [Episode 595]  Actor loss: -7.36167, Critic loss: 0.40182
# [Episode 596]  Actor loss: -4.32921, Critic loss: 0.78327
# [Episode 597]  Actor loss: -7.34100, Critic loss: 1.18584
# [Episode 598]  Actor loss: -3.05459, Critic loss: 1.55376
# [Episode 599]  Actor loss: -7.42160, Critic loss: 1.11293
# [Episode 600]  Actor loss: 0.05419, Critic loss: 0.90133
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 601]  Actor loss: -2.34234, Critic loss: 0.60638
# [Episode 602]  Actor loss: -4.63181, Critic loss: 0.41448
# [Episode 603]  Actor loss: -9.85337, Critic loss: 1.15854
# [Episode 604]  Actor loss: -4.00242, Critic loss: 0.36083
# [Episode 605]  Actor loss: -6.75024, Critic loss: 0.71461
# [Episode 606]  Actor loss: -6.31724, Critic loss: 1.16084
# [Episode 607]  Actor loss: -1.41415, Critic loss: 0.72139
# [Episode 608]  Actor loss: -7.54873, Critic loss: 0.74684
# [Episode 609]  Actor loss: -2.15841, Critic loss: 1.00267
# [Episode 610]  Actor loss: -4.46797, Critic loss: 0.64317
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 611]  Actor loss: -0.01228, Critic loss: 0.51308
# [Episode 612]  Actor loss: -8.81561, Critic loss: 0.71338
# [Episode 613]  Actor loss: -9.73639, Critic loss: 1.20853
# [Episode 614]  Actor loss: -2.34007, Critic loss: 0.76728
# [Episode 615]  Actor loss: -2.95964, Critic loss: 0.54506
# [Episode 616]  Actor loss: -2.86112, Critic loss: 0.28943
# [Episode 617]  Actor loss: -9.15675, Critic loss: 1.00410
# [Episode 618]  Actor loss: -4.67056, Critic loss: 1.11725
# [Episode 619]  Actor loss: -3.84665, Critic loss: 1.02681
# [Episode 620]  Actor loss: -8.09735, Critic loss: 1.05149
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 621]  Actor loss: -9.18782, Critic loss: 0.65784
# [Episode 622]  Actor loss: -4.40466, Critic loss: 0.87005
# [Episode 623]  Actor loss: -2.50541, Critic loss: 0.21290
# [Episode 624]  Actor loss: -4.59465, Critic loss: 0.47699
# [Episode 625]  Actor loss: -0.19977, Critic loss: 0.53365
# [Episode 626]  Actor loss: -3.54261, Critic loss: 0.53596
# [Episode 627]  Actor loss: -1.39652, Critic loss: 0.41893
# [Episode 628]  Actor loss: -9.63436, Critic loss: 1.17673
# [Episode 629]  Actor loss: -4.17027, Critic loss: 0.41234
# [Episode 630]  Actor loss: -6.96918, Critic loss: 0.42759
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 631]  Actor loss: -8.91591, Critic loss: 0.56528
# [Episode 632]  Actor loss: -2.25078, Critic loss: 0.42011
# [Episode 633]  Actor loss: -3.30770, Critic loss: 0.56794
# [Episode 634]  Actor loss: -6.96524, Critic loss: 0.79552
# [Episode 635]  Actor loss: -4.32888, Critic loss: 0.53338
# [Episode 636]  Actor loss: -1.45086, Critic loss: 0.38428
# [Episode 637]  Actor loss: -3.62654, Critic loss: 0.25260
# [Episode 638]  Actor loss: -2.24425, Critic loss: 0.52469
# [Episode 639]  Actor loss: -5.92032, Critic loss: 0.72809
# [Episode 640]  Actor loss: -5.37512, Critic loss: 0.27863
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 641]  Actor loss: -7.58551, Critic loss: 0.45692
# [Episode 642]  Actor loss: -4.64966, Critic loss: 0.36336
# [Episode 643]  Actor loss: -1.14751, Critic loss: 0.34436
# [Episode 644]  Actor loss: -6.29028, Critic loss: 0.13920
# [Episode 645]  Actor loss: -3.69538, Critic loss: 0.22713
# [Episode 646]  Actor loss: -2.51376, Critic loss: 0.29215
# [Episode 647]  Actor loss: -9.49967, Critic loss: 0.73037
# [Episode 648]  Actor loss: -7.82406, Critic loss: 0.66102
# [Episode 649]  Actor loss: -0.41231, Critic loss: 0.34626
# [Episode 650]  Actor loss: -14.00360, Critic loss: 0.93089
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 651]  Actor loss: -13.53248, Critic loss: 1.17106
# [Episode 652]  Actor loss: -0.77771, Critic loss: 0.89906
# [Episode 653]  Actor loss: -0.02876, Critic loss: 0.40829
# [Episode 654]  Actor loss: -9.49259, Critic loss: 1.05101
# [Episode 655]  Actor loss: -5.80344, Critic loss: 0.47713
# [Episode 656]  Actor loss: -3.46017, Critic loss: 0.34993
# [Episode 657]  Actor loss: -7.24237, Critic loss: 0.93191
# [Episode 658]  Actor loss: -1.31959, Critic loss: 0.61596
# [Episode 659]  Actor loss: -6.72261, Critic loss: 0.21881
# [Episode 660]  Actor loss: -5.96464, Critic loss: 0.40040
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 661]  Actor loss: -3.11668, Critic loss: 0.34125
# [Episode 662]  Actor loss: 0.26503, Critic loss: 0.47903
# [Episode 663]  Actor loss: -4.92287, Critic loss: 0.35403
# [Episode 664]  Actor loss: -14.09578, Critic loss: 0.85884
# [Episode 665]  Actor loss: -5.65356, Critic loss: 1.14213
# [Episode 666]  Actor loss: -6.93175, Critic loss: 0.89770
# [Episode 667]  Actor loss: -3.78399, Critic loss: 0.94479
# [Episode 668]  Actor loss: -1.75798, Critic loss: 0.33590
# [Episode 669]  Actor loss: -8.21542, Critic loss: 1.26846
# [Episode 670]  Actor loss: -3.03061, Critic loss: 0.75518
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 671]  Actor loss: -13.08943, Critic loss: 2.70326
# [Episode 672]  Actor loss: -9.54815, Critic loss: 1.14459
# [Episode 673]  Actor loss: -4.89011, Critic loss: 1.92448
# [Episode 674]  Actor loss: -2.33756, Critic loss: 0.50973
# [Episode 675]  Actor loss: -1.87027, Critic loss: 0.44463
# [Episode 676]  Actor loss: 0.47219, Critic loss: 0.47857
# [Episode 677]  Actor loss: -1.61902, Critic loss: 0.35205
# [Episode 678]  Actor loss: -1.57476, Critic loss: 0.68778
# [Episode 679]  Actor loss: -10.18360, Critic loss: 0.88932
# [Episode 680]  Actor loss: -3.07164, Critic loss: 0.54552
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 681]  Actor loss: -5.49642, Critic loss: 0.30154
# [Episode 682]  Actor loss: -3.76926, Critic loss: 0.43677
# [Episode 683]  Actor loss: -5.43660, Critic loss: 1.27367
# [Episode 684]  Actor loss: -1.45365, Critic loss: 0.53284
# [Episode 685]  Actor loss: -6.01350, Critic loss: 0.42578
# [Episode 686]  Actor loss: -13.34818, Critic loss: 0.94332
# [Episode 687]  Actor loss: -2.10850, Critic loss: 0.60877
# [Episode 688]  Actor loss: -6.95437, Critic loss: 0.88337
# [Episode 689]  Actor loss: -7.05371, Critic loss: 0.63683
# [Episode 690]  Actor loss: -10.02268, Critic loss: 1.04974
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 691]  Actor loss: -4.08891, Critic loss: 0.78945
# [Episode 692]  Actor loss: -11.53849, Critic loss: 2.82817
# [Episode 693]  Actor loss: 2.36194, Critic loss: 0.42065
# [Episode 694]  Actor loss: -8.61765, Critic loss: 1.18212
# [Episode 695]  Actor loss: 1.03937, Critic loss: 0.96648
# [Episode 696]  Actor loss: -1.61389, Critic loss: 0.44021
# [Episode 697]  Actor loss: -4.12261, Critic loss: 1.27538
# [Episode 698]  Actor loss: -4.42894, Critic loss: 1.01754
# [Episode 699]  Actor loss: -2.83629, Critic loss: 0.71899
# [Episode 700]  Actor loss: -8.00358, Critic loss: 1.18413
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 701]  Actor loss: -5.55730, Critic loss: 0.63372
# [Episode 702]  Actor loss: -8.04569, Critic loss: 0.77518
# [Episode 703]  Actor loss: -9.59476, Critic loss: 2.12026
# [Episode 704]  Actor loss: 1.24159, Critic loss: 1.13585
# [Episode 705]  Actor loss: -5.49259, Critic loss: 1.93597
# [Episode 706]  Actor loss: -5.90501, Critic loss: 1.68026
# [Episode 707]  Actor loss: 2.04481, Critic loss: 1.76599
# [Episode 708]  Actor loss: -2.90101, Critic loss: 0.66532
# [Episode 709]  Actor loss: 2.83813, Critic loss: 1.26617
# [Episode 710]  Actor loss: -7.59650, Critic loss: 0.81312
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 711]  Actor loss: -15.27928, Critic loss: 1.06645
# [Episode 712]  Actor loss: -6.68729, Critic loss: 1.40248
# ...
# [Episode 2176]  Actor loss: 8.33257, Critic loss: 4.34402
# [Episode 2177]  Actor loss: 1.28288, Critic loss: 1.73042
# [Episode 2178]  Actor loss: -9.06908, Critic loss: 3.03372
# [Episode 2179]  Actor loss: -7.19267, Critic loss: 1.81721
# [Episode 2180]  Actor loss: -18.50939, Critic loss: 3.42541
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2181]  Actor loss: -15.05291, Critic loss: 3.47578
# [Episode 2182]  Actor loss: -11.16295, Critic loss: 2.33375
# [Episode 2183]  Actor loss: -18.14868, Critic loss: 3.36041
# [Episode 2184]  Actor loss: -18.48523, Critic loss: 3.63234
# [Episode 2185]  Actor loss: -5.15638, Critic loss: 4.04222
# [Episode 2186]  Actor loss: -7.94435, Critic loss: 4.81335
# [Episode 2187]  Actor loss: -2.01838, Critic loss: 3.66912
# [Episode 2188]  Actor loss: -9.14577, Critic loss: 2.59615
# [Episode 2189]  Actor loss: -7.94489, Critic loss: 2.33415
# [Episode 2190]  Actor loss: -38.42627, Critic loss: 4.55417
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2191]  Actor loss: -22.07970, Critic loss: 5.96839
# [Episode 2192]  Actor loss: 0.86547, Critic loss: 3.12673
# [Episode 2193]  Actor loss: 2.78446, Critic loss: 1.91754
# [Episode 2194]  Actor loss: -0.53246, Critic loss: 4.80888
# [Episode 2195]  Actor loss: 15.69845, Critic loss: 4.25995
# [Episode 2196]  Actor loss: 2.11377, Critic loss: 2.09447
# [Episode 2197]  Actor loss: 0.04318, Critic loss: 5.72184
# [Episode 2198]  Actor loss: -23.49064, Critic loss: 3.94429
# [Episode 2199]  Actor loss: -19.74860, Critic loss: 3.87225
# [Episode 2200]  Actor loss: -21.75017, Critic loss: 6.33290
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2201]  Actor loss: -1.79695, Critic loss: 2.86047
# [Episode 2202]  Actor loss: -9.80319, Critic loss: 3.92963
# [Episode 2203]  Actor loss: -26.89797, Critic loss: 5.80233
# [Episode 2204]  Actor loss: -9.43685, Critic loss: 3.46529
# [Episode 2205]  Actor loss: -10.34715, Critic loss: 2.18153
# [Episode 2206]  Actor loss: -35.89676, Critic loss: 5.12000
# [Episode 2207]  Actor loss: -38.29614, Critic loss: 6.39867
# [Episode 2208]  Actor loss: -4.20169, Critic loss: 7.21848
# [Episode 2209]  Actor loss: -17.66960, Critic loss: 8.61485
# [Episode 2210]  Actor loss: 18.39157, Critic loss: 9.54260
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2211]  Actor loss: 20.12464, Critic loss: 9.27367
# [Episode 2212]  Actor loss: -18.33385, Critic loss: 4.37835
# [Episode 2213]  Actor loss: -15.81746, Critic loss: 4.49002
# [Episode 2214]  Actor loss: 4.20369, Critic loss: 5.65808
# [Episode 2215]  Actor loss: 0.32468, Critic loss: 7.41642
# [Episode 2216]  Actor loss: 16.47075, Critic loss: 6.41575
# [Episode 2217]  Actor loss: -18.43013, Critic loss: 6.26394
# [Episode 2218]  Actor loss: -6.12961, Critic loss: 5.05009
# [Episode 2219]  Actor loss: 5.28040, Critic loss: 3.50025
# [Episode 2220]  Actor loss: 2.49222, Critic loss: 7.69889
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2221]  Actor loss: -17.69964, Critic loss: 5.69804
# [Episode 2222]  Actor loss: -17.97436, Critic loss: 5.98120
# [Episode 2223]  Actor loss: 8.59245, Critic loss: 8.09963
# [Episode 2224]  Actor loss: -1.27161, Critic loss: 5.49707
# [Episode 2225]  Actor loss: 0.49088, Critic loss: 4.05190
# [Episode 2226]  Actor loss: -30.83926, Critic loss: 4.73242
# [Episode 2227]  Actor loss: -22.30615, Critic loss: 2.84148
# [Episode 2228]  Actor loss: -24.24235, Critic loss: 3.65564
# [Episode 2229]  Actor loss: -3.66453, Critic loss: 6.39306
# [Episode 2230]  Actor loss: -5.24961, Critic loss: 4.75732
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2231]  Actor loss: -16.19441, Critic loss: 4.96623
# [Episode 2232]  Actor loss: 9.45926, Critic loss: 3.27547
# [Episode 2233]  Actor loss: -3.49807, Critic loss: 2.58811
# [Episode 2234]  Actor loss: 8.59892, Critic loss: 2.54007
# [Episode 2235]  Actor loss: -3.57564, Critic loss: 3.61541
# [Episode 2236]  Actor loss: -10.29829, Critic loss: 7.09210
# [Episode 2237]  Actor loss: -6.95183, Critic loss: 3.66070
# [Episode 2238]  Actor loss: -20.31427, Critic loss: 5.28674
# [Episode 2239]  Actor loss: -15.59745, Critic loss: 3.14240
# [Episode 2240]  Actor loss: -1.38432, Critic loss: 3.48962
# Test average reward is -2.0, Current best average reward is 1.0
#
# [Episode 2241]  Actor loss: -3.73681, Critic loss: 3.03182
# [Episode 2242]  Actor loss: -5.98097, Critic loss: 5.27504
# [Episode 2243]  Actor loss: -10.55637, Critic loss: 5.59141
# [Episode 2244]  Actor loss: -5.89879, Critic loss: 1.89874
# [Episode 2245]  Actor loss: -13.26411, Critic loss: 8.19948
# [Episode 2246]  Actor loss: -9.06096, Critic loss: 3.39336
# [Episode 2247]  Actor loss: -9.69403, Critic loss: 5.41336
# [Episode 2248]  Actor loss: 8.93258, Critic loss: 4.08736
# [Episode 2249]  Actor loss: -10.17120, Critic loss: 4.66197
# [Episode 2250]  Actor loss: 11.36232, Critic loss: 4.01044
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2251]  Actor loss: -11.87590, Critic loss: 3.67676
# [Episode 2252]  Actor loss: -25.41597, Critic loss: 2.57657
# [Episode 2253]  Actor loss: -1.82362, Critic loss: 4.26899
# [Episode 2254]  Actor loss: -6.03198, Critic loss: 2.81296
# [Episode 2255]  Actor loss: 2.57440, Critic loss: 4.50999
# [Episode 2256]  Actor loss: -13.61358, Critic loss: 5.45337
# [Episode 2257]  Actor loss: -6.27972, Critic loss: 2.08775
# [Episode 2258]  Actor loss: -31.99103, Critic loss: 3.99944
# [Episode 2259]  Actor loss: -8.26825, Critic loss: 4.56817
# [Episode 2260]  Actor loss: -12.54374, Critic loss: 6.79675
# Test average reward is -3.0, Current best average reward is 1.0
#
# [Episode 2261]  Actor loss: -29.04960, Critic loss: 4.76492
# [Episode 2262]  Actor loss: -28.84115, Critic loss: 6.29677
# [Episode 2263]  Actor loss: -12.55117, Critic loss: 9.55618
# [Episode 2264]  Actor loss: 10.45201, Critic loss: 9.48270
# [Episode 2265]  Actor loss: 13.86137, Critic loss: 4.67257
# [Episode 2266]  Actor loss: -9.21882, Critic loss: 3.35521
# [Episode 2267]  Actor loss: -2.40651, Critic loss: 8.02061
# [Episode 2268]  Actor loss: -8.63996, Critic loss: 3.26041
# [Episode 2269]  Actor loss: -26.32785, Critic loss: 3.54205
# [Episode 2270]  Actor loss: -24.22965, Critic loss: 3.72723
# Test average reward is 1.0, Current best average reward is 1.0
#
# [Episode 2271]  Actor loss: -14.59781, Critic loss: 5.60707
# [Episode 2272]  Actor loss: -20.82750, Critic loss: 3.75323
# [Episode 2273]  Actor loss: -16.27518, Critic loss: 4.16046
# [Episode 2274]  Actor loss: -7.57125, Critic loss: 7.19508
# [Episode 2275]  Actor loss: -16.68393, Critic loss: 3.03249
# [Episode 2276]  Actor loss: -7.16055, Critic loss: 8.17648
# [Episode 2277]  Actor loss: 16.33665, Critic loss: 4.66890
# [Episode 2278]  Actor loss: -13.63081, Critic loss: 4.53879
# [Episode 2279]  Actor loss: -15.89003, Critic loss: 5.97865
# [Episode 2280]  Actor loss: -34.85846, Critic loss: 4.03993
# Test average reward is -2.0, Current best average reward is 1.0
#
# [Episode 2281]  Actor loss: -1.18540, Critic loss: 15.32282
# [Episode 2282]  Actor loss: 7.77899, Critic loss: 6.65009
# [Episode 2283]  Actor loss: 25.38189, Critic loss: 5.31994
# [Episode 2284]  Actor loss: 13.10490, Critic loss: 4.67246
# [Episode 2285]  Actor loss: 9.81620, Critic loss: 4.27487
# [Episode 2286]  Actor loss: -9.96515, Critic loss: 2.94126
# [Episode 2287]  Actor loss: 1.68669, Critic loss: 2.23357
# [Episode 2288]  Actor loss: -16.86966, Critic loss: 4.88773
# [Episode 2289]  Actor loss: -3.28821, Critic loss: 8.97243
# [Episode 2290]  Actor loss: -8.06694, Critic loss: 6.10595
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2291]  Actor loss: -18.66121, Critic loss: 3.53619
# [Episode 2292]  Actor loss: -7.67324, Critic loss: 4.24579
# [Episode 2293]  Actor loss: -5.96885, Critic loss: 2.73434
# [Episode 2294]  Actor loss: 10.02928, Critic loss: 2.57645
# [Episode 2295]  Actor loss: 2.99427, Critic loss: 1.28589
# [Episode 2296]  Actor loss: -7.89040, Critic loss: 4.10500
# [Episode 2297]  Actor loss: -28.13645, Critic loss: 2.80850
# [Episode 2298]  Actor loss: -35.24466, Critic loss: 2.89355
# [Episode 2299]  Actor loss: -16.22065, Critic loss: 5.32649
# [Episode 2300]  Actor loss: -21.64661, Critic loss: 3.04561
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2301]  Actor loss: -11.31358, Critic loss: 3.34655
# [Episode 2302]  Actor loss: -17.62298, Critic loss: 2.84844
# [Episode 2303]  Actor loss: -4.89598, Critic loss: 3.30485
# [Episode 2304]  Actor loss: 7.21527, Critic loss: 4.74510
# [Episode 2305]  Actor loss: 4.20986, Critic loss: 4.36768
# [Episode 2306]  Actor loss: -18.81283, Critic loss: 4.90491
# [Episode 2307]  Actor loss: -9.86660, Critic loss: 2.73094
# [Episode 2308]  Actor loss: -5.86628, Critic loss: 2.94184
# [Episode 2309]  Actor loss: -5.39168, Critic loss: 6.61202
# [Episode 2310]  Actor loss: 4.75564, Critic loss: 5.10116
# Test average reward is -5.0, Current best average reward is 1.0
#
# [Episode 2311]  Actor loss: -3.84580, Critic loss: 7.64614
# [Episode 2312]  Actor loss: 6.45519, Critic loss: 5.80382
# [Episode 2313]  Actor loss: 10.12608, Critic loss: 2.94130
# [Episode 2314]  Actor loss: -16.91944, Critic loss: 5.12896
# [Episode 2315]  Actor loss: -4.86568, Critic loss: 6.37188
# [Episode 2316]  Actor loss: -10.34388, Critic loss: 6.35467
# [Episode 2317]  Actor loss: -20.07325, Critic loss: 4.47443
# [Episode 2318]  Actor loss: -18.65924, Critic loss: 7.75928
# [Episode 2319]  Actor loss: -7.58622, Critic loss: 9.74024
# [Episode 2320]  Actor loss: 5.10491, Critic loss: 5.13382
# Test average reward is 4.0, Current best average reward is 1.0
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2320_4.0\assets
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2320_4.0\assets
# WARNING:py.warnings:C:\Users\User\AppData\Local\Temp\ipykernel_15740\2018008081.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   reward = env.act(env.getActionSet()[int(action.numpy())])
# [Episode 2321]  Actor loss: 7.33283, Critic loss: 7.34643
# [Episode 2322]  Actor loss: 1.35224, Critic loss: 3.80649
# [Episode 2323]  Actor loss: 1.86097, Critic loss: 4.10653
# [Episode 2324]  Actor loss: -13.61712, Critic loss: 4.23372
# [Episode 2325]  Actor loss: -1.99655, Critic loss: 3.84457
# [Episode 2326]  Actor loss: 5.92649, Critic loss: 3.91007
# [Episode 2327]  Actor loss: 6.93934, Critic loss: 2.94370
# [Episode 2328]  Actor loss: -1.36205, Critic loss: 2.60139
# [Episode 2329]  Actor loss: -7.71097, Critic loss: 2.79667
# [Episode 2330]  Actor loss: 1.33343, Critic loss: 1.90963
# Test average reward is -4.0, Current best average reward is 4.0
#
# [Episode 2331]  Actor loss: -12.75954, Critic loss: 3.11631
# [Episode 2332]  Actor loss: -11.85751, Critic loss: 1.40916
# [Episode 2333]  Actor loss: -29.98627, Critic loss: 4.45024
# [Episode 2334]  Actor loss: -18.24068, Critic loss: 5.21579
# [Episode 2335]  Actor loss: -9.89185, Critic loss: 3.68873
# [Episode 2336]  Actor loss: -11.62977, Critic loss: 3.83526
# [Episode 2337]  Actor loss: -11.18535, Critic loss: 2.87746
# [Episode 2338]  Actor loss: -22.89042, Critic loss: 5.03850
# [Episode 2339]  Actor loss: -22.32199, Critic loss: 5.39694
# [Episode 2340]  Actor loss: -14.95851, Critic loss: 2.98385
# Test average reward is -5.0, Current best average reward is 4.0
#
# [Episode 2341]  Actor loss: -20.93757, Critic loss: 4.83240
# [Episode 2342]  Actor loss: 6.43178, Critic loss: 4.14017
# [Episode 2343]  Actor loss: 6.15075, Critic loss: 8.10761
# [Episode 2344]  Actor loss: -25.87208, Critic loss: 5.85958
# [Episode 2345]  Actor loss: -26.29041, Critic loss: 7.82460
# [Episode 2346]  Actor loss: 15.82758, Critic loss: 11.28221
# [Episode 2347]  Actor loss: -35.73645, Critic loss: 5.76114
# [Episode 2348]  Actor loss: -12.18333, Critic loss: 5.65026
# [Episode 2349]  Actor loss: -8.63257, Critic loss: 3.24826
# [Episode 2350]  Actor loss: -21.09136, Critic loss: 9.58047
# Test average reward is -5.0, Current best average reward is 4.0
#
# [Episode 2351]  Actor loss: -12.18036, Critic loss: 14.33719
# [Episode 2352]  Actor loss: -37.88385, Critic loss: 4.30927
# [Episode 2353]  Actor loss: -11.69711, Critic loss: 6.02573
# [Episode 2354]  Actor loss: -18.03185, Critic loss: 5.52920
# [Episode 2355]  Actor loss: -26.00541, Critic loss: 7.24440
# [Episode 2356]  Actor loss: -9.01719, Critic loss: 4.27514
# [Episode 2357]  Actor loss: -10.59515, Critic loss: 7.15982
# [Episode 2358]  Actor loss: 9.89633, Critic loss: 11.39108
# [Episode 2359]  Actor loss: 18.24004, Critic loss: 7.81084
# [Episode 2360]  Actor loss: -7.02070, Critic loss: 5.86815
# Test average reward is -5.0, Current best average reward is 4.0
#
# [Episode 2361]  Actor loss: 1.29976, Critic loss: 13.28191
# [Episode 2362]  Actor loss: -9.34516, Critic loss: 9.22060
# [Episode 2363]  Actor loss: 2.64178, Critic loss: 7.26929
# [Episode 2364]  Actor loss: -22.36890, Critic loss: 5.58112
# [Episode 2365]  Actor loss: -11.36185, Critic loss: 5.48007
# [Episode 2366]  Actor loss: -18.67583, Critic loss: 5.81329
# [Episode 2367]  Actor loss: -6.54226, Critic loss: 9.35081
# [Episode 2368]  Actor loss: -21.77184, Critic loss: 8.80991
# [Episode 2369]  Actor loss: -45.58426, Critic loss: 3.28875
# [Episode 2370]  Actor loss: -25.18311, Critic loss: 11.15610
# Test average reward is -1.0, Current best average reward is 4.0
#
# [Episode 2371]  Actor loss: -13.43643, Critic loss: 7.53109
# [Episode 2372]  Actor loss: 4.10679, Critic loss: 7.72323
# [Episode 2373]  Actor loss: -11.69830, Critic loss: 5.34113
# [Episode 2374]  Actor loss: -29.53553, Critic loss: 5.42657
# [Episode 2375]  Actor loss: -6.05913, Critic loss: 13.22345
# [Episode 2376]  Actor loss: 17.78512, Critic loss: 6.31313
# [Episode 2377]  Actor loss: 14.60848, Critic loss: 9.86742
# [Episode 2378]  Actor loss: -8.14401, Critic loss: 5.07525
# [Episode 2379]  Actor loss: -20.24255, Critic loss: 7.20831
# [Episode 2380]  Actor loss: -20.36634, Critic loss: 7.04917
# Test average reward is -5.0, Current best average reward is 4.0
#
# [Episode 2381]  Actor loss: -15.85810, Critic loss: 10.40659
# [Episode 2382]  Actor loss: -13.45497, Critic loss: 5.49721
# [Episode 2383]  Actor loss: 10.02775, Critic loss: 6.68766
# [Episode 2384]  Actor loss: 6.67112, Critic loss: 5.95214
# [Episode 2385]  Actor loss: -2.88639, Critic loss: 6.04924
# [Episode 2386]  Actor loss: 2.57112, Critic loss: 2.82201
# [Episode 2387]  Actor loss: 15.98085, Critic loss: 7.01354
# [Episode 2388]  Actor loss: 2.51912, Critic loss: 3.84748
# [Episode 2389]  Actor loss: -15.78367, Critic loss: 6.68353
# [Episode 2390]  Actor loss: 16.15542, Critic loss: 6.44778
# Test average reward is -4.0, Current best average reward is 4.0
#
# [Episode 2391]  Actor loss: -2.85032, Critic loss: 3.12829
# [Episode 2392]  Actor loss: -18.46154, Critic loss: 3.36444
# [Episode 2393]  Actor loss: -16.24371, Critic loss: 5.07088
# [Episode 2394]  Actor loss: -20.23528, Critic loss: 4.84378
# [Episode 2395]  Actor loss: -25.14564, Critic loss: 3.99450
# [Episode 2396]  Actor loss: -2.20386, Critic loss: 2.56839
# [Episode 2397]  Actor loss: -22.38056, Critic loss: 7.05994
# [Episode 2398]  Actor loss: -22.39385, Critic loss: 4.96075
# [Episode 2399]  Actor loss: -17.36772, Critic loss: 3.08097
# [Episode 2400]  Actor loss: -25.64597, Critic loss: 4.55527
# Test average reward is 10.0, Current best average reward is 4.0
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2400_10.0\assets
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2400_10.0\assets

# %% [markdown]
# ## Report
#
# * Since this Lab's topic is mainly on GAE and PPO, I focus on the comprehension of these two parts.
#     * **GAE (Generalized Advantage Estimation):**
#         * GAE is a method used to estimate the "Advantage Function" to balance bias and variance
#         * In policy gradient methods, we need to estimate the "relative value" of performing a specific action in a certain state, which is the advantage function A(s, a)
#         * GAE reduces the high variance problem when calculating long-term returns while being more accurate than simple TD methods
#         * In **compute_gae** function, it calculates the advantage values for each step in reverse order, which are used for updating the policy and value function
#     * **PPO (Proximal Policy Optimization):**
#         * PPO is an improved policy gradient method designed to make updates more stable and avoid drastic changes to the policy
#         * PPO maximizes the objective function L(θ), while limiting policy updates to prevent instability
#         * PPO's clipping ensures updates remain within a safe range, improving stability
#         ```
#         ratio = tf.math.exp(new_log_probs - old_log_probs)
#         surr1 = ratio * advantage
#         surr2 = tf.clip_by_value(ratio, 1.0 - self.clip_pram, 1.0 + self.clip_pram) * advantage
#
#         actor_loss = tf.math.negative(tf.math.reduce_mean(tf.math.minimum(surr1, surr2))) - 0.1 * entropy
#         ```
#         * This part is the key step in PPO, calculating the Actor's loss for stable policy updates
#             * ratio: Computes the ratio between new and old policies
#             * clip_by_value: Limits the ratio within [1−ϵ,1+ϵ]
#             * entropy: Encourages exploration by adding a regularization term to avoid premature convergence
# * **Discovery**
#     * It takes **2400** episodes to train the policy to make the bird get more than 10 rewards (pass 10 tunnels) in one run.
#     * It takes a lot more time to train Flappy Bird to achieve basic performance with GAExPPO technique than SARSA or Q-learning method from last Lab:
#         * For SARSA, it takes about 4 hours;
#         * For Q-learning, it takes about 7 hours;
#         * For GAExPPO, it takes about 8 hours.
#     * Nevertheless, the performance:
#         * **SARSA = Q-learning >> GAExPPO**
#         * I think the reason is that the SARSA and Q-learning perform well on easy task such as Flappy Bird because of the **discrete action space**; yet the GAExPPO technique performs well on more complicated task with **continuous action space**.
