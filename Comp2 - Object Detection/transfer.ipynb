# %%
import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
IMAGE_SIZE = 448
NUM_CLASSES = 20
BOXES_PER_CELL = 2
CELL_SIZE = 7

# %%
def conv_leaky_relu(inputs, filters, size, stride):
    x = tf.keras.layers.Conv2D(filters, size, stride, padding="same",)(inputs)
    x = tf.keras.layers.LeakyReLU(0.1)(x)
    return x

# %%
def residual_block(inputs, filters, size, stride, kernel_init: str='zeros'):
    x = tf.keras.layers.Conv2D(
        filters, size, stride, padding="same",
        kernel_initializer=kernel_init
    )(inputs)
    x = tf.keras.layers.LeakyReLU(0.1)(x)
    x = x + inputs
    return x

# %%
def yolo():
    yolo_input = tf.keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    pretrained_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    pretrained_model.trainable = False

    x = pretrained_model(yolo_input)

    x = conv_leaky_relu(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)
    x = conv_leaky_relu(x, 1024, 3, 2)
    x = tf.keras.layers.BatchNormalization()(x)

    x = conv_leaky_relu(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)
    x = conv_leaky_relu(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(4096, kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.01))(x)
    x = tf.keras.layers.LeakyReLU(0.1)(x)

    yolo_outputs = tf.keras.layers.Dense(CELL_SIZE * CELL_SIZE * (NUM_CLASSES + BOXES_PER_CELL * 5),
                            kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.01))(x)

    return tf.keras.Model(inputs=yolo_input, outputs=yolo_outputs, name="YOLO")

def new_yolo():
    yolo_input = tf.keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    pretrained_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    pretrained_model.trainable = False

    x = pretrained_model(yolo_input)

    x = conv_leaky_relu(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)
    x = conv_leaky_relu(x, 1024, 3, 2)
    x = tf.keras.layers.BatchNormalization()(x)

    x = conv_leaky_relu(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)
    x = conv_leaky_relu(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)

    # Add 2 layers without changing the model
    x = residual_block(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)
    x = residual_block(x, 1024, 3, 1)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(4096, kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.01))(x)
    x = tf.keras.layers.LeakyReLU(0.1)(x)

    yolo_outputs = tf.keras.layers.Dense(CELL_SIZE * CELL_SIZE * (NUM_CLASSES + BOXES_PER_CELL * 5),
                            kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.01))(x)

    return tf.keras.Model(inputs=yolo_input, outputs=yolo_outputs, name="new-YOLO")

# %%
# reload_from_ckpt = '../ckpts/YOLO-Resnet50-from-ep8-ep32/yolo-31'
reload_from_ckpt = './ckpt-load/yolo-20'


old_YOLO = yolo()
# new_YOLO = new_yolo()

if reload_from_ckpt is not None:
    ckpt = tf.train.Checkpoint(net=old_YOLO)
    ckpt.restore(reload_from_ckpt)

# %%
for var in tf.train.list_variables(reload_from_ckpt):
    print(var)  # 檢查權重的名稱和形狀
# Out:
# ('_CHECKPOINTABLE_OBJECT_GRAPH', [])
# ('epoch/.ATTRIBUTES/VARIABLE_VALUE', [])
# ('net/layer_with_weights-0/layer_with_weights-0/bias/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-0/kernel/.ATTRIBUTES/VARIABLE_VALUE', [7, 7, 3, 64])
# ('net/layer_with_weights-0/layer_with_weights-1/beta/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-1/gamma/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-1/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-1/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-10/bias/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-10/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 64])
# ('net/layer_with_weights-0/layer_with_weights-100/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-100/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 2048, 512])
# ('net/layer_with_weights-0/layer_with_weights-101/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-101/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-101/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-101/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-102/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-102/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 512, 512])
# ('net/layer_with_weights-0/layer_with_weights-103/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-103/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-103/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-103/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-104/bias/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-104/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 2048])
# ('net/layer_with_weights-0/layer_with_weights-105/beta/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-105/gamma/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-105/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-105/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-11/beta/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-11/gamma/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-11/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-11/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-12/bias/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-12/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 64, 64])
# ('net/layer_with_weights-0/layer_with_weights-13/beta/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-13/gamma/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-13/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-13/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-14/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-14/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 64, 256])
# ('net/layer_with_weights-0/layer_with_weights-15/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-15/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-15/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-15/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-16/bias/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-16/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 64])
# ('net/layer_with_weights-0/layer_with_weights-17/beta/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-17/gamma/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-17/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-17/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-18/bias/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-18/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 64, 64])
# ('net/layer_with_weights-0/layer_with_weights-19/beta/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-19/gamma/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-19/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-19/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-2/bias/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-2/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 64, 64])
# ('net/layer_with_weights-0/layer_with_weights-20/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-20/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 64, 256])
# ('net/layer_with_weights-0/layer_with_weights-21/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-21/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-21/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-21/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-22/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-22/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 128])
# ('net/layer_with_weights-0/layer_with_weights-23/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-23/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-23/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-23/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-24/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-24/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 128, 128])
# ('net/layer_with_weights-0/layer_with_weights-25/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-25/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-25/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-25/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-26/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-26/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 512])
# ('net/layer_with_weights-0/layer_with_weights-27/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-27/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 128, 512])
# ('net/layer_with_weights-0/layer_with_weights-28/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-28/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-28/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-28/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-29/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-29/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-29/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-29/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-3/beta/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-3/gamma/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-3/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-3/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-30/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-30/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 128])
# ('net/layer_with_weights-0/layer_with_weights-31/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-31/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-31/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-31/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-32/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-32/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 128, 128])
# ('net/layer_with_weights-0/layer_with_weights-33/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-33/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-33/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-33/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-34/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-34/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 128, 512])
# ('net/layer_with_weights-0/layer_with_weights-35/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-35/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-35/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-35/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-36/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-36/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 128])
# ('net/layer_with_weights-0/layer_with_weights-37/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-37/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-37/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-37/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-38/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-38/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 128, 128])
# ('net/layer_with_weights-0/layer_with_weights-39/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-39/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-39/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-39/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-4/bias/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-4/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 64, 64])
# ('net/layer_with_weights-0/layer_with_weights-40/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-40/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 128, 512])
# ('net/layer_with_weights-0/layer_with_weights-41/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-41/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-41/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-41/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-42/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-42/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 128])
# ('net/layer_with_weights-0/layer_with_weights-43/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-43/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-43/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-43/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-44/bias/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-44/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 128, 128])
# ('net/layer_with_weights-0/layer_with_weights-45/beta/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-45/gamma/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-45/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-45/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [128])
# ('net/layer_with_weights-0/layer_with_weights-46/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-46/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 128, 512])
# ('net/layer_with_weights-0/layer_with_weights-47/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-47/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-47/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-47/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-48/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-48/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 256])
# ('net/layer_with_weights-0/layer_with_weights-49/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-49/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-49/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-49/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-5/beta/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-5/gamma/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-5/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-5/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [64])
# ('net/layer_with_weights-0/layer_with_weights-50/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-50/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 256, 256])
# ('net/layer_with_weights-0/layer_with_weights-51/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-51/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-51/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-51/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-52/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-52/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 1024])
# ('net/layer_with_weights-0/layer_with_weights-53/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-53/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 1024])
# ('net/layer_with_weights-0/layer_with_weights-54/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-54/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-54/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-54/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-55/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-55/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-55/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-55/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-56/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-56/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 1024, 256])
# ('net/layer_with_weights-0/layer_with_weights-57/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-57/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-57/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-57/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-58/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-58/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 256, 256])
# ('net/layer_with_weights-0/layer_with_weights-59/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-59/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-59/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-59/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-6/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-6/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 64, 256])
# ('net/layer_with_weights-0/layer_with_weights-60/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-60/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 1024])
# ('net/layer_with_weights-0/layer_with_weights-61/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-61/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-61/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-61/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-62/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-62/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 1024, 256])
# ('net/layer_with_weights-0/layer_with_weights-63/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-63/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-63/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-63/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-64/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-64/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 256, 256])
# ('net/layer_with_weights-0/layer_with_weights-65/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-65/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-65/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-65/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-66/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-66/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 1024])
# ('net/layer_with_weights-0/layer_with_weights-67/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-67/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-67/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-67/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-68/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-68/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 1024, 256])
# ('net/layer_with_weights-0/layer_with_weights-69/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-69/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-69/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-69/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-7/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-7/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 64, 256])
# ('net/layer_with_weights-0/layer_with_weights-70/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-70/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 256, 256])
# ('net/layer_with_weights-0/layer_with_weights-71/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-71/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-71/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-71/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-72/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-72/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 1024])
# ('net/layer_with_weights-0/layer_with_weights-73/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-73/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-73/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-73/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-74/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-74/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 1024, 256])
# ('net/layer_with_weights-0/layer_with_weights-75/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-75/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-75/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-75/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-76/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-76/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 256, 256])
# ('net/layer_with_weights-0/layer_with_weights-77/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-77/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-77/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-77/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-78/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-78/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 1024])
# ('net/layer_with_weights-0/layer_with_weights-79/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-79/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-79/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-79/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-8/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-8/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-8/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-8/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-80/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-80/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 1024, 256])
# ('net/layer_with_weights-0/layer_with_weights-81/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-81/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-81/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-81/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-82/bias/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-82/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 256, 256])
# ('net/layer_with_weights-0/layer_with_weights-83/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-83/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-83/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-83/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-84/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-84/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 256, 1024])
# ('net/layer_with_weights-0/layer_with_weights-85/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-85/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-85/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-85/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-0/layer_with_weights-86/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-86/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 1024, 512])
# ('net/layer_with_weights-0/layer_with_weights-87/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-87/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-87/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-87/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-88/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-88/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 512, 512])
# ('net/layer_with_weights-0/layer_with_weights-89/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-89/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-89/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-89/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-9/beta/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-9/gamma/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-9/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-9/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [256])
# ('net/layer_with_weights-0/layer_with_weights-90/bias/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-90/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 1024, 2048])
# ('net/layer_with_weights-0/layer_with_weights-91/bias/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-91/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 2048])
# ('net/layer_with_weights-0/layer_with_weights-92/beta/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-92/gamma/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-92/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-92/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-93/beta/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-93/gamma/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-93/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-93/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-94/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-94/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 2048, 512])
# ('net/layer_with_weights-0/layer_with_weights-95/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-95/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-95/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-95/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-96/bias/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-96/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 512, 512])
# ('net/layer_with_weights-0/layer_with_weights-97/beta/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-97/gamma/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-97/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-97/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [512])
# ('net/layer_with_weights-0/layer_with_weights-98/bias/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-98/kernel/.ATTRIBUTES/VARIABLE_VALUE', [1, 1, 512, 2048])
# ('net/layer_with_weights-0/layer_with_weights-99/beta/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-99/gamma/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-99/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-0/layer_with_weights-99/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [2048])
# ('net/layer_with_weights-1/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-1/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 2048, 1024])
# ('net/layer_with_weights-10/bias/.ATTRIBUTES/VARIABLE_VALUE', [1470])
# ('net/layer_with_weights-10/kernel/.ATTRIBUTES/VARIABLE_VALUE', [4096, 1470])
# ('net/layer_with_weights-2/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-2/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-2/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-2/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-3/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-3/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 1024, 1024])
# ('net/layer_with_weights-4/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-4/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-4/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-4/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-5/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-5/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 1024, 1024])
# ('net/layer_with_weights-6/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-6/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-6/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-6/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-7/bias/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-7/kernel/.ATTRIBUTES/VARIABLE_VALUE', [3, 3, 1024, 1024])
# ('net/layer_with_weights-8/beta/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-8/gamma/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-8/moving_mean/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-8/moving_variance/.ATTRIBUTES/VARIABLE_VALUE', [1024])
# ('net/layer_with_weights-9/bias/.ATTRIBUTES/VARIABLE_VALUE', [4096])
# ('net/layer_with_weights-9/kernel/.ATTRIBUTES/VARIABLE_VALUE', [50176, 4096])
# ('save_counter/.ATTRIBUTES/VARIABLE_VALUE', [])

# %%
for idx, layer in enumerate(old_YOLO.layers):
    print(idx, layer)
# Out:
# 0 <keras.engine.input_layer.InputLayer object at 0x0000027327CDEBB0>
# 1 <keras.engine.functional.Functional object at 0x000002732F9763D0>
# 2 <keras.layers.convolutional.conv2d.Conv2D object at 0x000002732F9658B0>
# 3 <keras.layers.activation.leaky_relu.LeakyReLU object at 0x000002732F956A30>
# 4 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002732F956C10>
# 5 <keras.layers.convolutional.conv2d.Conv2D object at 0x000002732F94CFA0>
# 6 <keras.layers.activation.leaky_relu.LeakyReLU object at 0x000002732F96CDF0>
# 7 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002733FE60160>
# 8 <keras.layers.convolutional.conv2d.Conv2D object at 0x000002732F94C5E0>
# 9 <keras.layers.activation.leaky_relu.LeakyReLU object at 0x000002732F9569D0>
# 10 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002733FE70AC0>
# 11 <keras.layers.convolutional.conv2d.Conv2D object at 0x000002733FE60CD0>
# 12 <keras.layers.activation.leaky_relu.LeakyReLU object at 0x000002733FE60640>
# 13 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002733FE67190>
# 14 <keras.layers.reshaping.flatten.Flatten object at 0x000002733FE85430>
# 15 <keras.layers.core.dense.Dense object at 0x000002733FE85AF0>
# 16 <keras.layers.activation.leaky_relu.LeakyReLU object at 0x000002733FE67FA0>
# 17 <keras.layers.core.dense.Dense object at 0x000002733FE67760>

# %%
old_YOLO_indices = [i for i, layer in enumerate(old_YOLO.layers)]
for _ in range(6):
    old_YOLO_indices.insert(14, -1)

new_YOLO_indices = [i for i, layer in enumerate(new_YOLO.layers)]

for old_id, new_id in zip(old_YOLO_indices, new_YOLO_indices):
    if old_id == -1:
        continue

    old_layer = old_YOLO.layers[old_id]
    new_layer = new_YOLO.layers[new_id]

    print("{}: Setting layer {} to layer: {}".format(new_id, old_layer.name, new_layer.name))

    new_layer.set_weights(old_layer.get_weights())
# Out:
# 0: Setting layer input_1 to layer: input_3
# 1: Setting layer resnet50 to layer: resnet50
# 2: Setting layer conv2d to layer: conv2d_4
# 3: Setting layer leaky_re_lu to layer: leaky_re_lu_5
# 4: Setting layer batch_normalization to layer: batch_normalization_4
# 5: Setting layer conv2d_1 to layer: conv2d_5
# 6: Setting layer leaky_re_lu_1 to layer: leaky_re_lu_6
# 7: Setting layer batch_normalization_1 to layer: batch_normalization_5
# 8: Setting layer conv2d_2 to layer: conv2d_6
# 9: Setting layer leaky_re_lu_2 to layer: leaky_re_lu_7
# 10: Setting layer batch_normalization_2 to layer: batch_normalization_6
# 11: Setting layer conv2d_3 to layer: conv2d_7
# 12: Setting layer leaky_re_lu_3 to layer: leaky_re_lu_8
# 13: Setting layer batch_normalization_3 to layer: batch_normalization_7
# 20: Setting layer flatten to layer: tf.__operators__.add_1
# 21: Setting layer dense to layer: batch_normalization_9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 16
#      12 new_layer = new_YOLO.layers[new_id]
#      14 print("{}: Setting layer {} to layer: {}".format(new_id, old_layer.name, new_layer.name))
# ---> 16 new_layer.set_weights(old_layer.get_weights())
#
# File c:\Users\Steven\AppData\Local\miniconda3\envs\dl\lib\site-packages\keras\engine\base_layer.py:1747, in Layer.set_weights(self, weights)
#    1744         expected_num_weights += 1
#    1746 if expected_num_weights != len(weights):
# -> 1747     raise ValueError(
#    1748         'You called `set_weights(weights)` on layer "%s" '
#    1749         "with a weight list of length %s, but the layer was "
#    1750         "expecting %s weights. Provided weights: %s..."
#    1751         % (
#    1752             self.name,
#    1753             len(weights),
#    1754             expected_num_weights,
#    1755             str(weights)[:50],
#    1756         )
#    1757     )
#    1759 weight_index = 0
#    1760 weight_value_tuples = []
#
# ValueError: You called `set_weights(weights)` on layer "batch_normalization_9" with a weight list of length 2, but the layer was expecting 4 weights. Provided weights: [array([[ 0.0073933 , -0.00091103, -0.00607041, .....

# %%
ckpt = tf.train.Checkpoint(epoch=tf.Variable(0), net=new_YOLO)

# manager = tf.train.CheckpointManager(ckpt, './ckpts/new-YOLO-Resnet50', max_to_keep=3,
#                                      checkpoint_name='yolo')
manager = tf.train.CheckpointManager(ckpt, './ckpt-save', max_to_keep=3,
                                     checkpoint_name='yolo')

save_path = manager.save()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).epoch
